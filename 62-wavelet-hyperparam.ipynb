# %%
# %matplotlib inline
import glob
import pandas as pd
import mne
import matplotlib.pyplot as plt
from io import StringIO
import mne
from mne.io import read_raw_eeglab, read_epochs_eeglab
import numpy as np
from scipy import signal
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from tqdm import tqdm_notebook

from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVR
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.tree import DecisionTreeClassifier
from keras_tqdm import TQDMNotebookCallback
from tensorboard.plugins.hparams import api as hp
from livelossplot.tf_keras import PlotLossesCallback

import autosklearn.regression
import sklearn.model_selection
import sklearn.datasets
import sklearn.metrics
import multiprocessing
from tpot import TPOTRegressor
from oct2py import octave

from joblib import Parallel, delayed
import multiprocessing
from joblib import wrap_non_picklable_objects
import json
import pickle
import os.path
from mpl_toolkits.mplot3d import axes3d
import tensorflow as tf
from tensorflow.keras import layers
import timeit
# Out:
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# Using TensorFlow backend.
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/pyparsing.py:2927: FutureWarning: Possible set intersection at position 3
#   self.re = re.compile( self.reString )

# %%
eeglab_path = '/home/raquib/Documents/MATLAB/eeglab2019_0/functions/'
octave.addpath(eeglab_path + 'guifunc');
octave.addpath(eeglab_path + 'popfunc');
octave.addpath(eeglab_path + 'adminfunc');
octave.addpath(eeglab_path + 'sigprocfunc');
octave.addpath(eeglab_path + 'miscfunc');
# Out:
# warning: function /home/raquib/Documents/MATLAB/eeglab2019_0/functions/sigprocfunc/quantile.m shadows a core library function

# %%
experiment = 'data/original/*/*'
meps = sorted(glob.glob(experiment + '/mep/*/*.txt'))
mep_present = len(meps) > 0
eegs = sorted(glob.glob(experiment + '/eeg/*/clean-prestimulus.set'))
eeg_present = len(eegs) > 0
cmaps = sorted(glob.glob(experiment + '/cmap/*.xlsx'))
cmap_present = len(cmaps) > 0
all_present = mep_present and eeg_present and cmap_present
print(all_present)
# Out:
# True

# %%
print('EEG count: ' + str(len(eegs)))
print('MEP count: ' + str(len(meps)))
print('CMAP count: ' + str(len(cmaps)))
# Out:
# EEG count: 44
# MEP count: 77
# CMAP count: 22

# %%
eegs
# Out:
# ['data/original/sub03/exp01/eeg/SP 110RMT r1/clean-prestimulus.set',
#  'data/original/sub03/exp01/eeg/SP 110RMT r2/clean-prestimulus.set',
#  'data/original/sub03/exp01/eeg/SP 110RMT r3/clean-prestimulus.set',
#  'data/original/sub03/exp02/eeg/SP 110RMT r1/clean-prestimulus.set',
#  'data/original/sub03/exp02/eeg/SP 110RMT r2/clean-prestimulus.set',
#  'data/original/sub03/exp03/eeg/SP 110RMT r1/clean-prestimulus.set',
#  'data/original/sub03/exp03/eeg/SP 110RMT r2/clean-prestimulus.set',
#  'data/original/sub03/exp03/eeg/SP 110RMT r3/clean-prestimulus.set',
#  'data/original/sub04/exp01/eeg/SP 110RMT r1/clean-prestimulus.set',
#  'data/original/sub04/exp01/eeg/SP 110RMT r2/clean-prestimulus.set',
#  'data/original/sub04/exp01/eeg/SP 110RMT r3/clean-prestimulus.set',
#  'data/original/sub05/exp01/eeg/SP 110RMT r3/clean-prestimulus.set',
#  'data/original/sub05/exp02/eeg/SP 120RMT r2/clean-prestimulus.set',
#  'data/original/sub06/exp01/eeg/SP 110RMT r1/clean-prestimulus.set',
#  'data/original/sub06/exp01/eeg/SP 110RMT r2/clean-prestimulus.set',
#  'data/original/sub06/exp01/eeg/SP 110RMT r3/clean-prestimulus.set',
#  'data/original/sub06/exp02/eeg/SP 110RMT/clean-prestimulus.set',
#  'data/original/sub07/exp01/eeg/SP 110RMT r1/clean-prestimulus.set',
#  'data/original/sub07/exp01/eeg/SP 110RMT r2/clean-prestimulus.set',
#  'data/original/sub07/exp01/eeg/SP 110RMT r3/clean-prestimulus.set',
#  'data/original/sub08/exp01/eeg/SP 110RMT r1/clean-prestimulus.set',
#  'data/original/sub08/exp01/eeg/SP 110RMT r2/clean-prestimulus.set',
#  'data/original/sub08/exp01/eeg/SP 110RMT r3/clean-prestimulus.set',
#  'data/original/sub08/exp02/eeg/SP 110RMT/clean-prestimulus.set',
#  'data/original/sub08/exp03/eeg/SP 110RMT r1/clean-prestimulus.set',
#  'data/original/sub08/exp03/eeg/SP 110RMT r2/clean-prestimulus.set',
#  'data/original/sub08/exp03/eeg/SP 110RMT r3/clean-prestimulus.set',
#  'data/original/sub09/exp01/eeg/SP 110RMT/clean-prestimulus.set',
#  'data/original/sub10/exp01/eeg/SP 110RMT/clean-prestimulus.set',
#  'data/original/sub10/exp02/eeg/SP 110RMT r1/clean-prestimulus.set',
#  'data/original/sub10/exp02/eeg/SP 110RMT r2/clean-prestimulus.set',
#  'data/original/sub10/exp02/eeg/SP 110RMT r3/clean-prestimulus.set',
#  'data/original/sub11/exp01/eeg/SP 110RMT/clean-prestimulus.set',
#  'data/original/sub11/exp02/eeg/SP 110RMT/clean-prestimulus.set',
#  'data/original/sub12/exp01/eeg/SP 110RMT/clean-prestimulus.set',
#  'data/original/sub12/exp02/eeg/SP 110RMT/clean-prestimulus.set',
#  'data/original/sub13/exp01/eeg/SP 110RMT/clean-prestimulus.set',
#  'data/original/sub14/exp01/eeg/SP 110RMT r1/clean-prestimulus.set',
#  'data/original/sub15/exp01/eeg/SP 110RMT r1/clean-prestimulus.set',
#  'data/original/sub15/exp01/eeg/SP 110RMT r2/clean-prestimulus.set',
#  'data/original/sub15/exp01/eeg/SP 110RMT r3/clean-prestimulus.set',
#  'data/original/sub16/exp01/eeg/SP 110RMT r1/clean-prestimulus.set',
#  'data/original/sub16/exp01/eeg/SP 110RMT r2/clean-prestimulus.set',
#  'data/original/sub16/exp01/eeg/SP 110RMT r3/clean-prestimulus.set']

# %%
eegs = [
    'data/original/sub03/exp01/eeg/SP 110RMT r1/clean-prestimulus.set',
    'data/original/sub03/exp01/eeg/SP 110RMT r2/clean-prestimulus.set',
    'data/original/sub03/exp01/eeg/SP 110RMT r3/clean-prestimulus.set',
#     'data/original/sub03/exp02/eeg/SP 110RMT r1/clean-prestimulus.set', NO CMAP
#     'data/original/sub03/exp02/eeg/SP 110RMT r2/clean-prestimulus.set', NO CMAP
#     'data/original/sub03/exp03/eeg/SP 110RMT r1/clean-prestimulus.set', NO CMAP
    'data/original/sub03/exp03/eeg/SP 110RMT r2/clean-prestimulus.set',
    'data/original/sub03/exp03/eeg/SP 110RMT r3/clean-prestimulus.set',
#     'data/original/sub04/exp01/eeg/SP 110RMT r1/clean-prestimulus.set', NO CMAP
#     'data/original/sub04/exp01/eeg/SP 110RMT r2/clean-prestimulus.set', NO CMAP
#     'data/original/sub04/exp01/eeg/SP 110RMT r3/clean-prestimulus.set', NO CMAP
#     'data/original/sub05/exp01/eeg/SP 110RMT r3/clean-prestimulus.set',
    'data/original/sub06/exp01/eeg/SP 110RMT r1/clean-prestimulus.set',
    'data/original/sub06/exp01/eeg/SP 110RMT r2/clean-prestimulus.set',
    'data/original/sub06/exp01/eeg/SP 110RMT r3/clean-prestimulus.set',
    'data/original/sub06/exp02/eeg/SP 110RMT/clean-prestimulus.set',
    'data/original/sub07/exp01/eeg/SP 110RMT r1/clean-prestimulus.set',
    'data/original/sub07/exp01/eeg/SP 110RMT r2/clean-prestimulus.set',
    'data/original/sub07/exp01/eeg/SP 110RMT r3/clean-prestimulus.set',
    'data/original/sub08/exp01/eeg/SP 110RMT r1/clean-prestimulus.set',
    'data/original/sub08/exp01/eeg/SP 110RMT r2/clean-prestimulus.set',
    'data/original/sub08/exp01/eeg/SP 110RMT r3/clean-prestimulus.set',
    'data/original/sub08/exp02/eeg/SP 110RMT/clean-prestimulus.set',
    'data/original/sub08/exp03/eeg/SP 110RMT r1/clean-prestimulus.set',
    'data/original/sub08/exp03/eeg/SP 110RMT r2/clean-prestimulus.set',
    'data/original/sub08/exp03/eeg/SP 110RMT r3/clean-prestimulus.set',
    'data/original/sub12/exp02/eeg/SP 110RMT/clean-prestimulus.set',
    'data/original/sub13/exp01/eeg/SP 110RMT/clean-prestimulus.set',
    'data/original/sub14/exp01/eeg/SP 110RMT r1/clean-prestimulus.set',
    'data/original/sub15/exp01/eeg/SP 110RMT r1/clean-prestimulus.set',
    'data/original/sub15/exp01/eeg/SP 110RMT r2/clean-prestimulus.set',
    'data/original/sub15/exp01/eeg/SP 110RMT r3/clean-prestimulus.set',
    'data/original/sub16/exp01/eeg/SP 110RMT r1/clean-prestimulus.set',
    'data/original/sub16/exp01/eeg/SP 110RMT r2/clean-prestimulus.set',
    'data/original/sub16/exp01/eeg/SP 110RMT r3/clean-prestimulus.set'
]

# %% [markdown]
# # Read and process EEG

# %%
def read_eeg(path):
    eeg = octave.pop_loadset(path)
    new_trial_list = []
    for i in range(eeg.data.shape[2]):
        trial = eeg.data[:, :, i]
        time = np.linspace(-1000, -20, num=trial.shape[1])
        trial = pd.DataFrame(np.transpose(trial), columns=eeg.chanlocs.labels[0])
        trial['time'] = time
        new_trial_list.append(trial)
    return new_trial_list

def crop_trials(trial_list, duration_millis=500, sampling_rate=2048):
    new_trial_list = []
    for trial in trial_list:
        samples_to_pick = duration_millis * sampling_rate / 1000
        new_trial_list.append(trial.tail(int(samples_to_pick)))
    return new_trial_list, samples_to_pick

# Calculate EEG area.
def calculate_eeg_area(epoch_df, sf=2048):
    y = epoch_df.drop('time', axis=1).mean(axis=1)
    b2, a2 = signal.butter(4, 200/(sf/2), btype='lowpass')
    envelope = signal.filtfilt(b2, a2, np.abs(y))
    area = np.trapz(envelope, epoch_df['time'].values)
    return area

# Calculate EEG frequency.
def calculate_eeg_frequency(channel):
    sf = 2048
    win = 4 * sf
    freqs, psd = signal.welch(channel, sf, nperseg=win)
    return freqs, psd

def calculate_eeg_max_amplitude(epoch_df):
    avg = epoch_df.mean(axis=1)
    return np.max(avg.values)

def band_max(freq, psd, interval):
    indices = []
    for el in freq:
        indices.append(el in interval)
    freq = freq[indices]
    psd = psd[indices]
    if (len(psd) == 0):
        return 0, 0
    i = np.argmax(np.abs(psd))
    return freq[i], psd[i]

def filter_electrodes(trial, which='all'):
    time_column = trial['time']
    if which == 'ltm1':
        channel_names = ['FC5','FC1','C3','CP5','CP1','FC3','C5','C1','CP3']
    elif which == 'rtm1':
        channel_names = ['FC6','FC2','C4','CP6','CP2','FC4','C6','C2','CP4']
    elif which == 'central':
        channel_names = ['Fz','FCz','Cz','F1','FC1','C1','C2','FC2','F2']
    else:
        channel_names = ['Fp1', 'Fpz', 'Fp2', 'F7', 'F3', 'Fz', 'F4', 'F8', 'FC5', 'FC1', 'FC2', 'FC6', 'M1', 'T7', 'C3', 'Cz', 'C4', 'T8', 'M2', 'CP5', 'CP1', 'CP2', 'CP6', 'P7', 'P3', 'Pz', 'P4', 'P8', 'POz', 'O1', 'O2', 'EOG', 'AF7', 'AF3', 'AF4', 'AF8', 'F5', 'F1', 'F2', 'F6', 'FC3', 'FCz', 'FC4', 'C5', 'C1', 'C2', 'C6', 'CP3', 'CP4', 'P5', 'P1', 'P2', 'P6', 'PO5', 'PO3', 'PO4', 'PO6', 'FT7', 'FT8', 'TP7', 'TP8', 'PO7', 'PO8', 'Oz']
    trial = trial[channel_names]
    trial['time'] = time_column
    return trial

def read_wavelets(sub, exp, run, epoch_num):
    path = 'wavelets/' + sub + '-' + exp + '-' + run + '-' + str(epoch_num)
    with open(path + '-central.pickle', 'rb') as f:
        central = pickle.load(f)
    with open(path + '-ltm1.pickle', 'rb') as f:
        ltm1 = pickle.load(f)
    with open(path + '-rtm1.pickle', 'rb') as f:
        rtm1 = pickle.load(f)
    with open(path + '-all.pickle', 'rb') as f:
        all_channels = pickle.load(f)
    return all_channels, ltm1, rtm1, central

def wavelet_band_max(df, interval):
    indices = []
    for el in (df.index * 1000):
        indices.append(el in interval)
    df = df[indices]
    if (df.shape[0] == 0):
        return 0, 0, 0, 0
    return df.mean(axis=1).max(), df.mean(axis=1).argmax() * 1000, df.mean(axis=0).max(), df.mean(axis=0).argmax()

# %% [markdown]
# # Read features file

# %%
features_filename = '55-features-v1.xlsx'

# %%
df = pd.read_excel(features_filename, index_col=0)

p1 = np.percentile(df['mep_category_cmap'], 50)
cat = np.ones(len(df['mep_category_cmap'])) * (df['mep_category_cmap'] > p1)
df['mep_category_cmap_across_subjects'] = cat

# %% [markdown]
# # Prepare wavelet dataframe

# %%
start_time_sec = -100
end_time_sec = -20

wt_large_all_all, wt_large_ltm1_all, wt_large_rtm1_all, wt_large_central_all, wt_small_all_all, wt_small_ltm1_all, wt_small_rtm1_all, wt_small_central_all = np.zeros((52, 164)), np.zeros((52, 164)), np.zeros((52, 164)), np.zeros((52, 164)), np.zeros((52, 164)), np.zeros((52, 164)), np.zeros((52, 164)), np.zeros((52, 164))
wt_large_all_all_avg, wt_large_ltm1_all_avg, wt_large_rtm1_all_avg, wt_large_central_all_avg, wt_small_all_all_avg, wt_small_ltm1_all_avg, wt_small_rtm1_all_avg, wt_small_central_all_avg = np.zeros((52, 164)), np.zeros((52, 164)), np.zeros((52, 164)), np.zeros((52, 164)), np.zeros((52, 164)), np.zeros((52, 164)), np.zeros((52, 164)), np.zeros((52, 164))

df_wt = []
        
for idx, epoch in tqdm_notebook(df.iterrows(), total=df.shape[0]):
    wt_all, wt_ltm1, wt_rtm1, wt_central = read_wavelets(epoch['sub'], epoch['exp'], epoch['run'], epoch['epoch'])

    # Drop last 9 rows (freq 0 to 2Hz)
    wt_all = wt_all[(wt_all.index * 1000 > 6) * (wt_all.index * 1000 < 50)]
    wt_ltm1 = wt_ltm1[(wt_ltm1.index * 1000 > 6) * (wt_ltm1.index * 1000 < 50)]
    wt_rtm1 = wt_rtm1[(wt_rtm1.index * 1000 > 6) * (wt_rtm1.index * 1000 < 50)]
    wt_central = wt_central[(wt_central.index * 1000 > 6) * (wt_central.index * 1000 < 50)]

    # Take only last 100ms - 0
    wt_all = wt_all.loc[:, wt_all.columns.isin(wt_all.columns[(wt_all.columns >= (start_time_sec/1000)) * (wt_all.columns <= (end_time_sec/1000))])]
    wt_ltm1 = wt_ltm1.loc[:, wt_ltm1.columns.isin(wt_ltm1.columns[(wt_ltm1.columns >= (start_time_sec/1000)) * (wt_ltm1.columns <= (end_time_sec/1000))])]
    wt_rtm1 = wt_rtm1.loc[:, wt_rtm1.columns.isin(wt_rtm1.columns[(wt_rtm1.columns >= (start_time_sec/1000)) * (wt_rtm1.columns <= (end_time_sec/1000))])]
    wt_central = wt_central.loc[:, wt_central.columns.isin(wt_central.columns[(wt_central.columns >= (start_time_sec/1000)) * (wt_central.columns <= (end_time_sec/1000))])]
    
    df_wt.append(wt_ltm1)
#     val = wt_ltm1.values.flatten()
#     val = np.append(val, epoch['mep_category_cmap_across_subjects'])
#     df_wt.append(val)
# Out:
# HBox(children=(IntProgress(value=0, max=1400), HTML(value='')))

# %%
sns.heatmap(df_wt[50])

# %%
df_wt[0].shape
# Out:
# (25, 164)

# %% [markdown]
# # Keras

# %%
x = []
for wt in df_wt:
    x.append(wt.values.reshape(wt.shape[0], wt.shape[1], 1))
    
x = np.array(x)
y = cat

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=12)

# %%
cb = TQDMNotebookCallback(show_inner=False)
cb.on_train_batch_begin = cb.on_batch_begin
cb.on_train_batch_end = cb.on_batch_end
cb.on_test_begin = cb.on_train_begin
cb.on_test_end = cb.on_train_end
cb.on_test_batch_begin = cb.on_batch_begin
cb.on_test_batch_end = cb.on_batch_end

# %%
HP_NUM_UNITS = hp.HParam('num_units', hp.Discrete([256, 128]))
HP_DROPOUT = hp.HParam('dropout', hp.Discrete([0.3, 0.5]))
HP_LEARNING_RATE = hp.HParam('learning_rate', hp.Discrete([0.0001, 0.00001]))
HP_CNN_FILTER_1 = hp.HParam('filter_1', hp.Discrete([128, 32]))
HP_CNN_FILTER_2 = hp.HParam('filter_2', hp.Discrete([128, 32]))
HP_BATCH_NORM = hp.HParam('batch_norm', hp.Discrete([False, True]))
HP_CNN_KERNEL_X_1 = hp.HParam('kernel_1_x', hp.Discrete([20]))
HP_CNN_KERNEL_Y_1 = hp.HParam('kernel_1_y', hp.Discrete([50, 20]))
HP_CNN_KERNEL_X_2 = hp.HParam('kernel_2_x', hp.Discrete([20, 10]))
HP_CNN_KERNEL_Y_2 = hp.HParam('kernel_2_y', hp.Discrete([30, 20]))

with tf.summary.create_file_writer('logs/hparam_tuning').as_default():
    hp.hparams_config(
        hparams=[HP_NUM_UNITS, HP_DROPOUT, HP_LEARNING_RATE, HP_CNN_KERNEL_X_1, HP_CNN_KERNEL_Y_1, HP_CNN_KERNEL_X_2, HP_CNN_KERNEL_Y_2, HP_CNN_FILTER_1, HP_CNN_FILTER_2, HP_BATCH_NORM],
        metrics=[hp.Metric('accuracy', display_name='Accuracy')],
    )

# %%
# tf.debugging.set_log_device_placement(True)

def train_test_model(logdir, hparams):
    classifier = tf.keras.Sequential()

    classifier.add(tf.keras.layers.Conv2D(filters=hparams[HP_CNN_FILTER_1], kernel_size=(hparams[HP_CNN_KERNEL_X_1], hparams[HP_CNN_KERNEL_Y_1]), padding='same', activation='relu', input_shape=(x_train[0].shape[0], x_train[0].shape[1],1)))
    if hparams[HP_BATCH_NORM]:
        classifier.add(tf.keras.layers.BatchNormalization())
    classifier.add(tf.keras.layers.MaxPooling2D(pool_size=2))
    classifier.add(tf.keras.layers.Dropout(hparams[HP_DROPOUT]))

    classifier.add(tf.keras.layers.Conv2D(filters=hparams[HP_CNN_FILTER_2], kernel_size=(hparams[HP_CNN_KERNEL_X_2], hparams[HP_CNN_KERNEL_Y_2]), padding='same', activation='relu'))
    classifier.add(tf.keras.layers.MaxPooling2D(pool_size=2))
    classifier.add(tf.keras.layers.Dropout(hparams[HP_DROPOUT]))

    classifier.add(tf.keras.layers.Flatten())

    classifier.add(tf.keras.layers.Dense(hparams[HP_NUM_UNITS], activation='relu'))
    classifier.add(tf.keras.layers.Dropout(hparams[HP_DROPOUT]))
    classifier.add(tf.keras.layers.Dense(1, activation='sigmoid'))
    classifier.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hparams[HP_LEARNING_RATE]), loss='binary_crossentropy', metrics=['accuracy'])
    
    cb = [
        tf.keras.callbacks.TensorBoard(log_dir=logdir),
        hp.KerasCallback(logdir, hparams)
    ]
    classifier.fit(x_train, y_train, validation_data=(x_test, y_test), batch_size=32, epochs=200, callbacks=cb, verbose=0)
    
    _, accuracy = classifier.evaluate(x_test, y_test)
    return accuracy

# %%
session_num = 0
for batch_norm in HP_BATCH_NORM.domain.values:
    for dropout in HP_DROPOUT.domain.values:
        for filter_1 in HP_CNN_FILTER_1.domain.values:
            for filter_2 in HP_CNN_FILTER_2.domain.values:
                for num_units in HP_NUM_UNITS.domain.values:
                    for kernel_1_x in HP_CNN_KERNEL_X_1.domain.values:
                        for kernel_1_y in HP_CNN_KERNEL_Y_1.domain.values:
                            for kernel_2_x in HP_CNN_KERNEL_X_2.domain.values:
                                for kernel_2_y in HP_CNN_KERNEL_Y_2.domain.values:
                                    for lr in HP_LEARNING_RATE.domain.values:
                                        hparams = {
                                            HP_NUM_UNITS: num_units,
                                            HP_DROPOUT: dropout,
                                            HP_LEARNING_RATE: lr,
                                            HP_CNN_KERNEL_X_1: kernel_1_x,
                                            HP_CNN_KERNEL_Y_1: kernel_1_y,
                                            HP_CNN_KERNEL_X_2: kernel_2_x,
                                            HP_CNN_KERNEL_Y_2: kernel_2_y,
                                            HP_CNN_FILTER_1: filter_1,
                                            HP_CNN_FILTER_2: filter_2,
                                            HP_BATCH_NORM: batch_norm
                                        }
                                        run_name = "run-%d" % session_num
                                        print('--- Starting trial: %s' % run_name)
                                        print({h.name: hparams[h] for h in hparams})
                                        train_test_model('logs/tensorboard/62-wavelet-hyper-v2/' + run_name, hparams)
                                        session_num += 1
# Out:
# --- Starting trial: run-0
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# WARNING: Logging before flag parsing goes to stderr.
# W0820 13:54:08.416932 139865288841024 deprecation.py:323] From /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 350/350 [==============================] - 0s 101us/sample - loss: 0.7021 - accuracy: 0.5171
# --- Starting trial: run-1
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 102us/sample - loss: 0.8956 - accuracy: 0.5200
# --- Starting trial: run-2
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 152us/sample - loss: 0.7062 - accuracy: 0.5286
# --- Starting trial: run-3
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 148us/sample - loss: 1.5498 - accuracy: 0.5086
# --- Starting trial: run-4
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 105us/sample - loss: 0.7223 - accuracy: 0.5229
# --- Starting trial: run-5
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 104us/sample - loss: 1.0824 - accuracy: 0.5400
# --- Starting trial: run-6
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 147us/sample - loss: 0.7049 - accuracy: 0.5343
# --- Starting trial: run-7
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 152us/sample - loss: 2.6192 - accuracy: 0.4800
# --- Starting trial: run-8
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 118us/sample - loss: 0.7184 - accuracy: 0.5086
# --- Starting trial: run-9
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 120us/sample - loss: 0.7098 - accuracy: 0.5086
# --- Starting trial: run-10
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 165us/sample - loss: 0.7423 - accuracy: 0.4771
# --- Starting trial: run-11
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 168us/sample - loss: 1.6362 - accuracy: 0.5486
# --- Starting trial: run-12
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 122us/sample - loss: 0.7728 - accuracy: 0.5029
# --- Starting trial: run-13
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 120us/sample - loss: 1.3571 - accuracy: 0.5314
# --- Starting trial: run-14
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 166us/sample - loss: 0.8618 - accuracy: 0.5114
# --- Starting trial: run-15
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 166us/sample - loss: 1.7133 - accuracy: 0.5029
# --- Starting trial: run-16
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 101us/sample - loss: 0.7425 - accuracy: 0.5057
# --- Starting trial: run-17
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 105us/sample - loss: 7.6666 - accuracy: 0.5000
# --- Starting trial: run-18
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 148us/sample - loss: 0.8070 - accuracy: 0.5429
# --- Starting trial: run-19
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 151us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-20
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 105us/sample - loss: 0.6847 - accuracy: 0.5229
# --- Starting trial: run-21
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 104us/sample - loss: 1.2364 - accuracy: 0.5286
# --- Starting trial: run-22
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 153us/sample - loss: 0.6934 - accuracy: 0.5057
# --- Starting trial: run-23
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 150us/sample - loss: 7.6666 - accuracy: 0.5000
# --- Starting trial: run-24
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 121us/sample - loss: 0.8052 - accuracy: 0.5257
# --- Starting trial: run-25
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 131us/sample - loss: 1.2289 - accuracy: 0.5371
# --- Starting trial: run-26
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 164us/sample - loss: 0.7562 - accuracy: 0.5257
# --- Starting trial: run-27
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 166us/sample - loss: 1.6039 - accuracy: 0.5371
# --- Starting trial: run-28
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 137us/sample - loss: 0.8140 - accuracy: 0.5171
# --- Starting trial: run-29
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 121us/sample - loss: 1.2462 - accuracy: 0.5514
# --- Starting trial: run-30
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 161us/sample - loss: 0.6905 - accuracy: 0.5400
# --- Starting trial: run-31
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 166us/sample - loss: 7.6666 - accuracy: 0.5000
# --- Starting trial: run-32
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 120us/sample - loss: 0.7177 - accuracy: 0.5114
# --- Starting trial: run-33
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 124us/sample - loss: 2.9822 - accuracy: 0.5371
# --- Starting trial: run-34
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 229us/sample - loss: 0.7172 - accuracy: 0.5000
# --- Starting trial: run-35
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 197us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-36
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 127us/sample - loss: 0.7103 - accuracy: 0.5086
# --- Starting trial: run-37
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 115us/sample - loss: 7.6666 - accuracy: 0.5000
# --- Starting trial: run-38
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 237us/sample - loss: 0.7386 - accuracy: 0.5286
# --- Starting trial: run-39
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 200us/sample - loss: 2.1431 - accuracy: 0.5514
# --- Starting trial: run-40
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 136us/sample - loss: 0.8321 - accuracy: 0.4800
# --- Starting trial: run-41
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 134us/sample - loss: 1.2478 - accuracy: 0.5229
# --- Starting trial: run-42
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 232us/sample - loss: 0.8182 - accuracy: 0.4971
# --- Starting trial: run-43
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 216us/sample - loss: 7.6666 - accuracy: 0.5000
# --- Starting trial: run-44
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 148us/sample - loss: 0.8061 - accuracy: 0.4914
# --- Starting trial: run-45
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 138us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-46
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 217us/sample - loss: 0.7755 - accuracy: 0.5314
# --- Starting trial: run-47
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 236us/sample - loss: 0.9471 - accuracy: 0.5057
# --- Starting trial: run-48
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 137us/sample - loss: 0.8007 - accuracy: 0.4743
# --- Starting trial: run-49
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 120us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-50
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 201us/sample - loss: 0.8206 - accuracy: 0.4800
# --- Starting trial: run-51
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 196us/sample - loss: 3.8717 - accuracy: 0.4971
# --- Starting trial: run-52
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 120us/sample - loss: 0.7736 - accuracy: 0.5000
# --- Starting trial: run-53
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 119us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-54
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 203us/sample - loss: 1.2272 - accuracy: 0.4914
# --- Starting trial: run-55
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 216us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-56
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 136us/sample - loss: 1.1206 - accuracy: 0.4657
# --- Starting trial: run-57
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 118us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-58
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 219us/sample - loss: 1.0139 - accuracy: 0.4829
# --- Starting trial: run-59
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 236us/sample - loss: 0.8339 - accuracy: 0.4771
# --- Starting trial: run-60
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 135us/sample - loss: 1.1682 - accuracy: 0.4857
# --- Starting trial: run-61
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 134us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-62
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 223us/sample - loss: 1.4299 - accuracy: 0.5114
# --- Starting trial: run-63
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 218us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-64
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 155us/sample - loss: 0.7526 - accuracy: 0.5200
# --- Starting trial: run-65
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 156us/sample - loss: 0.8348 - accuracy: 0.5343
# --- Starting trial: run-66
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 298us/sample - loss: 0.7160 - accuracy: 0.5286
# --- Starting trial: run-67
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 301us/sample - loss: 1.3281 - accuracy: 0.5314
# --- Starting trial: run-68
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 180us/sample - loss: 0.7109 - accuracy: 0.5400
# --- Starting trial: run-69
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 145us/sample - loss: 1.1063 - accuracy: 0.5057
# --- Starting trial: run-70
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 331us/sample - loss: 0.8242 - accuracy: 0.5400
# --- Starting trial: run-71
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 329us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-72
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 214us/sample - loss: 0.7377 - accuracy: 0.5143
# --- Starting trial: run-73
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 216us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-74
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 366us/sample - loss: 0.7040 - accuracy: 0.5543
# --- Starting trial: run-75
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 353us/sample - loss: 0.7988 - accuracy: 0.5457
# --- Starting trial: run-76
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 218us/sample - loss: 0.7371 - accuracy: 0.5029
# --- Starting trial: run-77
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 208us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-78
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 377us/sample - loss: 0.8693 - accuracy: 0.5029
# --- Starting trial: run-79
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 402us/sample - loss: 7.6666 - accuracy: 0.5000
# --- Starting trial: run-80
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 148us/sample - loss: 0.6892 - accuracy: 0.5257
# --- Starting trial: run-81
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 147us/sample - loss: 1.0099 - accuracy: 0.5257
# --- Starting trial: run-82
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 298us/sample - loss: 0.7810 - accuracy: 0.5486
# --- Starting trial: run-83
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 290us/sample - loss: 1.2901 - accuracy: 0.5629
# --- Starting trial: run-84
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 153us/sample - loss: 0.7920 - accuracy: 0.5743
# --- Starting trial: run-85
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 153us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-86
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 329us/sample - loss: 0.8998 - accuracy: 0.5171
# --- Starting trial: run-87
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 325us/sample - loss: 2.9975 - accuracy: 0.5400
# --- Starting trial: run-88
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 225us/sample - loss: 0.7158 - accuracy: 0.5229
# --- Starting trial: run-89
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 213us/sample - loss: 0.7207 - accuracy: 0.5286
# --- Starting trial: run-90
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 363us/sample - loss: 0.7324 - accuracy: 0.5457
# --- Starting trial: run-91
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 356us/sample - loss: 0.6984 - accuracy: 0.4971
# --- Starting trial: run-92
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 207us/sample - loss: 0.7974 - accuracy: 0.5457
# --- Starting trial: run-93
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 216us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-94
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 382us/sample - loss: 1.0098 - accuracy: 0.5171
# --- Starting trial: run-95
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 381us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-96
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 190us/sample - loss: 0.7123 - accuracy: 0.5171
# --- Starting trial: run-97
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 190us/sample - loss: 7.6666 - accuracy: 0.5000
# --- Starting trial: run-98
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 409us/sample - loss: 0.7353 - accuracy: 0.5000
# --- Starting trial: run-99
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 406us/sample - loss: 2.4378 - accuracy: 0.5571
# --- Starting trial: run-100
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 204us/sample - loss: 0.7597 - accuracy: 0.5286
# --- Starting trial: run-101
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 215us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-102
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 443us/sample - loss: 0.7436 - accuracy: 0.5171
# --- Starting trial: run-103
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 441us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-104
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 253us/sample - loss: 0.7628 - accuracy: 0.5086
# --- Starting trial: run-105
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 251us/sample - loss: 7.6666 - accuracy: 0.5000
# --- Starting trial: run-106
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 465us/sample - loss: 0.8557 - accuracy: 0.5057
# --- Starting trial: run-107
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 465us/sample - loss: 7.6666 - accuracy: 0.5000
# --- Starting trial: run-108
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 276us/sample - loss: 1.0338 - accuracy: 0.5000
# --- Starting trial: run-109
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 263us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-110
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 498us/sample - loss: 0.8428 - accuracy: 0.5229
# --- Starting trial: run-111
# {'num_units': 128, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 500us/sample - loss: 7.6666 - accuracy: 0.5000
# --- Starting trial: run-112
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 190us/sample - loss: 0.8597 - accuracy: 0.4943
# --- Starting trial: run-113
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 207us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-114
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 401us/sample - loss: 0.9085 - accuracy: 0.4800
# --- Starting trial: run-115
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 410us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-116
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 207us/sample - loss: 1.1535 - accuracy: 0.4829
# --- Starting trial: run-117
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 206us/sample - loss: 7.6666 - accuracy: 0.5000
# --- Starting trial: run-118
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 443us/sample - loss: 1.9513 - accuracy: 0.4743
# --- Starting trial: run-119
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 439us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-120
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 252us/sample - loss: 1.1265 - accuracy: 0.4714
# --- Starting trial: run-121
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 258us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-122
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 465us/sample - loss: 1.4401 - accuracy: 0.4686
# --- Starting trial: run-123
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 459us/sample - loss: 7.6666 - accuracy: 0.5000
# --- Starting trial: run-124
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 259us/sample - loss: 1.6566 - accuracy: 0.4914
# --- Starting trial: run-125
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 272us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-126
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 507us/sample - loss: 2.5965 - accuracy: 0.4629
# --- Starting trial: run-127
# {'num_units': 256, 'dropout': 0.3, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 501us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-128
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 96us/sample - loss: 0.6920 - accuracy: 0.5286
# --- Starting trial: run-129
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 104us/sample - loss: 0.6932 - accuracy: 0.5000
# --- Starting trial: run-130
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 148us/sample - loss: 0.6935 - accuracy: 0.5486
# --- Starting trial: run-131
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 153us/sample - loss: 0.8201 - accuracy: 0.4886
# --- Starting trial: run-132
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 101us/sample - loss: 0.6910 - accuracy: 0.5543
# --- Starting trial: run-133
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 103us/sample - loss: 0.7077 - accuracy: 0.5171
# --- Starting trial: run-134
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 150us/sample - loss: 0.6913 - accuracy: 0.5286
# --- Starting trial: run-135
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 153us/sample - loss: 6.7844 - accuracy: 0.5543
# --- Starting trial: run-136
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 124us/sample - loss: 0.6919 - accuracy: 0.5257
# --- Starting trial: run-137
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 123us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-138
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 162us/sample - loss: 0.6927 - accuracy: 0.5143
# --- Starting trial: run-139
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 157us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-140
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 115us/sample - loss: 0.7064 - accuracy: 0.5057
# --- Starting trial: run-141
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 137us/sample - loss: 0.7187 - accuracy: 0.5200
# --- Starting trial: run-142
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 164us/sample - loss: 0.6967 - accuracy: 0.5200
# --- Starting trial: run-143
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 171us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-144
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 104us/sample - loss: 0.6954 - accuracy: 0.5171
# --- Starting trial: run-145
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 103us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-146
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 151us/sample - loss: 0.6943 - accuracy: 0.5200
# --- Starting trial: run-147
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 151us/sample - loss: 7.6666 - accuracy: 0.5000
# --- Starting trial: run-148
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 105us/sample - loss: 0.6935 - accuracy: 0.5000
# --- Starting trial: run-149
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 103us/sample - loss: 1.0918 - accuracy: 0.5057
# --- Starting trial: run-150
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 147us/sample - loss: 0.6931 - accuracy: 0.5000
# --- Starting trial: run-151
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 151us/sample - loss: 0.9920 - accuracy: 0.5200
# --- Starting trial: run-152
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 122us/sample - loss: 0.6993 - accuracy: 0.5257
# --- Starting trial: run-153
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 120us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-154
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 164us/sample - loss: 0.6940 - accuracy: 0.5286
# --- Starting trial: run-155
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 160us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-156
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 121us/sample - loss: 0.7033 - accuracy: 0.5286
# --- Starting trial: run-157
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 120us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-158
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 163us/sample - loss: 0.6973 - accuracy: 0.5143
# --- Starting trial: run-159
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 161us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-160
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 120us/sample - loss: 0.6931 - accuracy: 0.5000
# --- Starting trial: run-161
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 123us/sample - loss: 0.7935 - accuracy: 0.4971
# --- Starting trial: run-162
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 202us/sample - loss: 0.6929 - accuracy: 0.5486
# --- Starting trial: run-163
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 217us/sample - loss: 1.0749 - accuracy: 0.5057
# --- Starting trial: run-164
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 141us/sample - loss: 0.6915 - accuracy: 0.5571
# --- Starting trial: run-165
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 135us/sample - loss: 0.7876 - accuracy: 0.5000
# --- Starting trial: run-166
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 201us/sample - loss: 0.6924 - accuracy: 0.5486
# --- Starting trial: run-167
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 199us/sample - loss: 1.0612 - accuracy: 0.5086
# --- Starting trial: run-168
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 152us/sample - loss: 0.6936 - accuracy: 0.5486
# --- Starting trial: run-169
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 127us/sample - loss: 7.6666 - accuracy: 0.5000
# --- Starting trial: run-170
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 220us/sample - loss: 0.7044 - accuracy: 0.5286
# --- Starting trial: run-171
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 216us/sample - loss: 0.6926 - accuracy: 0.5229
# --- Starting trial: run-172
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 145us/sample - loss: 0.7039 - accuracy: 0.5314
# --- Starting trial: run-173
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 130us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-174
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 220us/sample - loss: 0.7083 - accuracy: 0.5057
# --- Starting trial: run-175
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 219us/sample - loss: 7.6666 - accuracy: 0.5000
# --- Starting trial: run-176
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 119us/sample - loss: 0.6938 - accuracy: 0.5200
# --- Starting trial: run-177
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 123us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-178
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 206us/sample - loss: 0.7036 - accuracy: 0.5286
# --- Starting trial: run-179
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 204us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-180
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 141us/sample - loss: 0.6987 - accuracy: 0.5114
# --- Starting trial: run-181
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 119us/sample - loss: 7.6666 - accuracy: 0.5000
# --- Starting trial: run-182
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 215us/sample - loss: 0.6990 - accuracy: 0.5171
# --- Starting trial: run-183
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 219us/sample - loss: 1.3498 - accuracy: 0.5229
# --- Starting trial: run-184
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 134us/sample - loss: 0.7341 - accuracy: 0.4714
# --- Starting trial: run-185
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 134us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-186
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 221us/sample - loss: 0.7279 - accuracy: 0.4943
# --- Starting trial: run-187
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 217us/sample - loss: 7.7125 - accuracy: 0.5000
# --- Starting trial: run-188
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 135us/sample - loss: 0.7452 - accuracy: 0.5371
# --- Starting trial: run-189
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 132us/sample - loss: 0.6931 - accuracy: 0.5000
# --- Starting trial: run-190
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 224us/sample - loss: 0.7433 - accuracy: 0.5343
# --- Starting trial: run-191
# {'num_units': 256, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 50, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 32, 'filter_2': 128, 'batch_norm': False}
# 350/350 [==============================] - 0s 220us/sample - loss: 0.6931 - accuracy: 0.5000
# --- Starting trial: run-192
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 155us/sample - loss: 0.6951 - accuracy: 0.4943
# --- Starting trial: run-193
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 156us/sample - loss: 0.6932 - accuracy: 0.5000
# --- Starting trial: run-194
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 298us/sample - loss: 0.6932 - accuracy: 0.4971
# --- Starting trial: run-195
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 10, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 292us/sample - loss: 7.6666 - accuracy: 0.5000
# --- Starting trial: run-196
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 180us/sample - loss: 0.6931 - accuracy: 0.5000
# --- Starting trial: run-197
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 20, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 177us/sample - loss: 0.9103 - accuracy: 0.5200
# --- Starting trial: run-198
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 1e-05, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}
# 350/350 [==============================] - 0s 340us/sample - loss: 0.6980 - accuracy: 0.5000
# --- Starting trial: run-199
# {'num_units': 128, 'dropout': 0.5, 'learning_rate': 0.0001, 'kernel_1_x': 20, 'kernel_1_y': 20, 'kernel_2_x': 20, 'kernel_2_y': 30, 'filter_1': 128, 'filter_2': 32, 'batch_norm': False}

# %%
y_pred = classifier.predict(x_test)
y_pred = (y_pred > 0.5)
print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
