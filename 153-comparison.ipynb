# %% [markdown]
# # Import everything

# %%
import glob
import pandas as pd
import mne
import matplotlib.pyplot as plt
from io import StringIO
import mne
from mne.io import read_raw_eeglab, read_epochs_eeglab
import numpy as np
from scipy import signal
from scipy import fftpack
import seaborn as sns
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
# from tqdm import tqdm, tqdm_notebook
from tqdm.notebook import tqdm
import math
from sklearn import preprocessing
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.svm import SVR
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from keras_tqdm import TQDMNotebookCallback
from tensorboard.plugins.hparams import api as hp
from livelossplot.tf_keras import PlotLossesCallback

import sklearn.model_selection
import sklearn.datasets
import sklearn.metrics
import multiprocessing
from tpot import TPOTRegressor
from oct2py import octave
from joblib import Parallel, delayed
import multiprocessing
from joblib import wrap_non_picklable_objects
import json
import pickle
import os.path
from mpl_toolkits.mplot3d import axes3d
import timeit
from skimage.transform import resize
from timeit import default_timer as timer
from datetime import timedelta
import json
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, optimizers, callbacks
from tensorflow.keras.models import Model, load_model
from tensorboard.plugins.hparams import api as hp
from tensorflow.keras.utils import plot_model
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.genmod import bayes_mixed_glm as glm
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import RFECV
from spectrum import arburg, arma2psd, pburg
import pylab
from scipy.signal import find_peaks, butter
from scipy.integrate import simps
from scipy.io import loadmat
from numpy import trapz
# Out:
# Using TensorFlow backend.
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# # Import some MATLAB libraries
# This helps us read .set files.

# %%
eeglab_path = '/home/raquib/Documents/MATLAB/eeglab2019_0/functions/'
octave.addpath(eeglab_path + 'guifunc')
octave.addpath(eeglab_path + 'popfunc')
octave.addpath(eeglab_path + 'adminfunc')
octave.addpath(eeglab_path + 'sigprocfunc')
octave.addpath(eeglab_path + 'miscfunc')
# Out:
# warning: function /home/raquib/Documents/MATLAB/eeglab2019_0/functions/sigprocfunc/quantile.m shadows a core library function
# '.:/home/raquib/Documents/MATLAB/eeglab2019_0/functions/sigprocfunc:/home/raquib/Documents/MATLAB/eeglab2019_0/functions/adminfunc:/home/raquib/Documents/MATLAB/eeglab2019_0/functions/popfunc:/home/raquib/Documents/MATLAB/eeglab2019_0/functions/guifunc:/home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/oct2py:/home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/octave_kernel:/usr/lib/x86_64-linux-gnu/octave/4.2.2/site/oct/x86_64-pc-linux-gnu:/usr/lib/x86_64-linux-gnu/octave/site/oct/api-v51/x86_64-pc-linux-gnu:/usr/lib/x86_64-linux-gnu/octave/site/oct/x86_64-pc-linux-gnu:/usr/share/octave/4.2.2/site/m:/usr/share/octave/site/api-v51/m:/usr/share/octave/site/m:/usr/share/octave/site/m/startup:/usr/lib/x86_64-linux-gnu/octave/4.2.2/oct/x86_64-pc-linux-gnu:/usr/share/octave/4.2.2/m:/usr/share/octave/4.2.2/m/audio:/usr/share/octave/4.2.2/m/debian:/usr/share/octave/4.2.2/m/deprecated:/usr/share/octave/4.2.2/m/elfun:/usr/share/octave/4.2.2/m/general:/usr/share/octave/4.2.2/m/geometry:/usr/share/octave/4.2.2/m/gui:/usr/share/octave/4.2.2/m/help:/usr/share/octave/4.2.2/m/image:/usr/share/octave/4.2.2/m/io:/usr/share/octave/4.2.2/m/java:/usr/share/octave/4.2.2/m/linear-algebra:/usr/share/octave/4.2.2/m/miscellaneous:/usr/share/octave/4.2.2/m/ode:/usr/share/octave/4.2.2/m/optimization:/usr/share/octave/4.2.2/m/path:/usr/share/octave/4.2.2/m/pkg:/usr/share/octave/4.2.2/m/plot:/usr/share/octave/4.2.2/m/plot/appearance:/usr/share/octave/4.2.2/m/plot/draw:/usr/share/octave/4.2.2/m/plot/util:/usr/share/octave/4.2.2/m/polynomial:/usr/share/octave/4.2.2/m/prefs:/usr/share/octave/4.2.2/m/profiler:/usr/share/octave/4.2.2/m/set:/usr/share/octave/4.2.2/m/signal:/usr/share/octave/4.2.2/m/sparse:/usr/share/octave/4.2.2/m/specfun:/usr/share/octave/4.2.2/m/special-matrix:/usr/share/octave/4.2.2/m/startup:/usr/share/octave/4.2.2/m/statistics:/usr/share/octave/4.2.2/m/statistics/base:/usr/share/octave/4.2.2/m/statistics/distributions:/usr/share/octave/4.2.2/m/statistics/models:/usr/share/octave/4.2.2/m/statistics/tests:/usr/share/octave/4.2.2/m/strings:/usr/share/octave/4.2.2/m/testfun:/usr/share/octave/4.2.2/m/time:/usr/share/octave/4.2.2/data'

# %%
eegs = sorted(glob.glob('data/original/*/*/eeg/SP 110RMT r*/06-clean-prestimulus-hjorth.mat'))

# eegs = ['data/original/sub03/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub03/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub03/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub03/exp03/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub03/exp03/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub03/exp03/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub04/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub04/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub04/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
# #  'data/original/sub05/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',  # NO MEP
# #  'data/original/sub05/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',  # NO MEP
#  'data/original/sub05/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub06/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub06/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub06/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub06/exp02/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub07/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub07/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub07/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub08/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub08/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub08/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub08/exp02/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub08/exp03/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub08/exp03/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub08/exp03/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub09/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub10/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub10/exp02/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub10/exp02/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub10/exp02/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub11/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub12/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub12/exp02/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub12/exp03/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub12/exp03/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub12/exp03/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',        
#  'data/original/sub13/exp02/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat', # Left handed
#  'data/original/sub13/exp02/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat', # Left handed
#  'data/original/sub13/exp02/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat', # Left handed
# # 'data/original/sub14/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',   # BAD MEP
# #  'data/original/sub14/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat', # BAD MEP
# # 'data/original/sub14/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',   # BAD MEP
#  'data/original/sub15/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub15/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub15/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub16/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub16/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub16/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub17/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub18/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub18/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub18/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub19/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub19/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub19/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat']

# Clean EEG rejected trials.
# rejected_trials = [
#     {'sub': 'sub03', 'exp': 'exp02', 'run': 'r1', 'trial': '*'},
#     {'sub': 'sub03', 'exp': 'exp02', 'run': 'r2', 'trial': '*'},
#     {'sub': 'sub05', 'exp': 'exp01', 'run': 'r3', 'trial': '*'},
#     {'sub': 'sub07', 'exp': 'exp01', 'run': 'r1', 'trial': '*'},
#     {'sub': 'sub09', 'exp': 'exp01', 'run': 'r1', 'trial': '*'},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r1', 'trial': '*'},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r2', 'trial': '*'},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': '*'},
#     {'sub': 'sub11', 'exp': 'exp01', 'run': 'r1', 'trial': '*'},
#     {'sub': 'sub11', 'exp': 'exp02', 'run': 'r1', 'trial': '*'},
#     {'sub': 'sub12', 'exp': 'exp01', 'run': 'r1', 'trial': '*'},
#     {'sub': 'sub15', 'exp': 'exp01', 'run': 'r1', 'trial': '*'},
#     {'sub': 'sub08', 'exp': 'exp03', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub09', 'exp': 'exp01', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub11', 'exp': 'exp02', 'run': 'r1', 'trial': 14},
#     {'sub': 'sub11', 'exp': 'exp02', 'run': 'r1', 'trial': 38},
#     {'sub': 'sub12', 'exp': 'exp01', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub12', 'exp': 'exp02', 'run': 'r1', 'trial': 14},
#     {'sub': 'sub12', 'exp': 'exp02', 'run': 'r1', 'trial': 36},
#     {'sub': 'sub12', 'exp': 'exp02', 'run': 'r1', 'trial': 44},
#     {'sub': 'sub12', 'exp': 'exp03', 'run': 'r1', 'trial': 11},
#     {'sub': 'sub12', 'exp': 'exp03', 'run': 'r1', 'trial': 15},
#     {'sub': 'sub12', 'exp': 'exp03', 'run': 'r1', 'trial': 16},
#     {'sub': 'sub12', 'exp': 'exp03', 'run': 'r1', 'trial': 17},
#     {'sub': 'sub12', 'exp': 'exp03', 'run': 'r1', 'trial': 24},
#     {'sub': 'sub12', 'exp': 'exp03', 'run': 'r1', 'trial': 25},
#     {'sub': 'sub12', 'exp': 'exp03', 'run': 'r1', 'trial': 26},
#     {'sub': 'sub12', 'exp': 'exp03', 'run': 'r1', 'trial': 27},
#     {'sub': 'sub12', 'exp': 'exp03', 'run': 'r1', 'trial': 28},
#     {'sub': 'sub12', 'exp': 'exp03', 'run': 'r1', 'trial': 29},
#     {'sub': 'sub12', 'exp': 'exp03', 'run': 'r1', 'trial': 30},
#     {'sub': 'sub12', 'exp': 'exp03', 'run': 'r1', 'trial': 32},
#     {'sub': 'sub03', 'exp': 'exp01', 'run': 'r2', 'trial': 0},
#     {'sub': 'sub03', 'exp': 'exp01', 'run': 'r3', 'trial': 0},
#     {'sub': 'sub03', 'exp': 'exp01', 'run': 'r3', 'trial': 5},
#     {'sub': 'sub03', 'exp': 'exp01', 'run': 'r3', 'trial': 6},
#     {'sub': 'sub03', 'exp': 'exp01', 'run': 'r3', 'trial': 8},
#     {'sub': 'sub04', 'exp': 'exp01', 'run': 'r2', 'trial': 16},
#     {'sub': 'sub04', 'exp': 'exp01', 'run': 'r2', 'trial': 21},
#     {'sub': 'sub04', 'exp': 'exp01', 'run': 'r2', 'trial': 22},
#     {'sub': 'sub04', 'exp': 'exp01', 'run': 'r2', 'trial': 23},
#     {'sub': 'sub05', 'exp': 'exp01', 'run': 'r3', 'trial': 3},
#     {'sub': 'sub05', 'exp': 'exp01', 'run': 'r3', 'trial': 4},
#     {'sub': 'sub05', 'exp': 'exp01', 'run': 'r3', 'trial': 5},
#     {'sub': 'sub05', 'exp': 'exp01', 'run': 'r3', 'trial': 26},
#     {'sub': 'sub05', 'exp': 'exp01', 'run': 'r3', 'trial': 3},
#     {'sub': 'sub05', 'exp': 'exp01', 'run': 'r3', 'trial': 3},
#     {'sub': 'sub06', 'exp': 'exp01', 'run': 'r2', 'trial': 37},
#     {'sub': 'sub06', 'exp': 'exp02', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub07', 'exp': 'exp01', 'run': 'r2', 'trial': 0},
#     {'sub': 'sub07', 'exp': 'exp01', 'run': 'r2', 'trial': 3},
#     {'sub': 'sub07', 'exp': 'exp01', 'run': 'r2', 'trial': 11},
#     {'sub': 'sub07', 'exp': 'exp01', 'run': 'r2', 'trial': 45},
#     {'sub': 'sub07', 'exp': 'exp01', 'run': 'r2', 'trial': 46},
#     {'sub': 'sub07', 'exp': 'exp01', 'run': 'r2', 'trial': 47},
#     {'sub': 'sub07', 'exp': 'exp01', 'run': 'r2', 'trial': 48},
#     {'sub': 'sub07', 'exp': 'exp01', 'run': 'r2', 'trial': 49},
#     {'sub': 'sub07', 'exp': 'exp01', 'run': 'r2', 'trial': 38},
#     {'sub': 'sub07', 'exp': 'exp01', 'run': 'r2', 'trial': 24},
#     {'sub': 'sub08', 'exp': 'exp02', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub09', 'exp': 'exp01', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub09', 'exp': 'exp01', 'run': 'r1', 'trial': 1},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 2},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 26},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 16},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 15},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 12},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r2', 'trial': 37},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r2', 'trial': 42},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 23},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 24},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 25},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 26},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 27},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 28},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 29},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 30},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 31},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 32},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 33},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 34},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 35},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 36},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 37},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 38},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 39},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 40},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 41},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 42},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 43},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 44},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 45},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 46},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 47},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 48},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 49},
#     {'sub': 'sub12', 'exp': 'exp01', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub12', 'exp': 'exp02', 'run': 'r1', 'trial': 44},
#     {'sub': 'sub12', 'exp': 'exp02', 'run': 'r1', 'trial': 36},
#     {'sub': 'sub12', 'exp': 'exp02', 'run': 'r1', 'trial': 14},
#     {'sub': 'sub12', 'exp': 'exp01', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub12', 'exp': 'exp02', 'run': 'r1', 'trial': 44},
#     {'sub': 'sub12', 'exp': 'exp02', 'run': 'r1', 'trial': 14},
#     {'sub': 'sub09', 'exp': 'exp01', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub16', 'exp': 'exp01', 'run': 'r3', 'trial': 14},
#     {'sub': 'sub15', 'exp': 'exp01', 'run': 'r2', 'trial': 36},
#     {'sub': 'sub15', 'exp': 'exp01', 'run': 'r2', 'trial': 14},
#     {'sub': 'sub19', 'exp': 'exp01', 'run': 'r1', 'trial': 0}
# ]

# Hjorth rejected trials.
# rejected_trials = [
    
#     {'sub': 'sub03', 'exp': 'exp02', 'run': 'r1', 'trial': '*'},
#     {'sub': 'sub03', 'exp': 'exp02', 'run': 'r2', 'trial': '*'},
#     {'sub': 'sub05', 'exp': 'exp01', 'run': 'r3', 'trial': '*'},
    
#     {'sub': 'sub05', 'exp': 'exp01', 'run': 'r1', 'trial': '*'}, # BAD MEP.
#     {'sub': 'sub05', 'exp': 'exp01', 'run': 'r2', 'trial': '*'}, # BAD MEP.
#     {'sub': 'sub14', 'exp': 'exp01', 'run': 'r1', 'trial': '*'}, # BAD MEP.
#     {'sub': 'sub14', 'exp': 'exp01', 'run': 'r2', 'trial': '*'}, # BAD MEP.
#     {'sub': 'sub14', 'exp': 'exp01', 'run': 'r3', 'trial': '*'}, # BAD MEP.
    
#     {'sub': 'sub05', 'exp': 'exp01', 'run': 'r3', 'trial': '*'},
#     {'sub': 'sub07', 'exp': 'exp01', 'run': 'r1', 'trial': '*'},
#     {'sub': 'sub09', 'exp': 'exp01', 'run': 'r1', 'trial': '*'},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r1', 'trial': '*'},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r2', 'trial': '*'},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': '*'},
#     {'sub': 'sub11', 'exp': 'exp01', 'run': 'r1', 'trial': '*'},
#     {'sub': 'sub11', 'exp': 'exp02', 'run': 'r1', 'trial': '*'},
#     {'sub': 'sub12', 'exp': 'exp01', 'run': 'r1', 'trial': '*'},
#     {'sub': 'sub16', 'exp': 'exp01', 'run': 'r1', 'trial': '*'},
#     {'sub': 'sub08', 'exp': 'exp03', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub09', 'exp': 'exp01', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub11', 'exp': 'exp02', 'run': 'r1', 'trial': 14},
#     {'sub': 'sub11', 'exp': 'exp02', 'run': 'r1', 'trial': 38},
#     {'sub': 'sub12', 'exp': 'exp01', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub12', 'exp': 'exp02', 'run': 'r1', 'trial': 14},
#     {'sub': 'sub12', 'exp': 'exp02', 'run': 'r1', 'trial': 36},
#     {'sub': 'sub12', 'exp': 'exp02', 'run': 'r1', 'trial': 44},
#     {'sub': 'sub03', 'exp': 'exp01', 'run': 'r2', 'trial': 0},
#     {'sub': 'sub06', 'exp': 'exp01', 'run': 'r2', 'trial': 37},
#     {'sub': 'sub07', 'exp': 'exp01', 'run': 'r2', 'trial': 38},
#     {'sub': 'sub07', 'exp': 'exp01', 'run': 'r2', 'trial': 24},
#     {'sub': 'sub08', 'exp': 'exp02', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub09', 'exp': 'exp01', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub09', 'exp': 'exp01', 'run': 'r1', 'trial': 1},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 2},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 26},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 18},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 17},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 16},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 15},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 14},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 13},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 12},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 11},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 10},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 9},
#     {'sub': 'sub10', 'exp': 'exp01', 'run': 'r1', 'trial': 8},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r1', 'trial': 14},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r1', 'trial': 15},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r1', 'trial': 31},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r1', 'trial': 37},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r1', 'trial': 41},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r2', 'trial': 37},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r2', 'trial': 42},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 23},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 24},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 25},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 26},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 27},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 28},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 29},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 30},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 31},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 32},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 33},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 34},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 35},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 36},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 37},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 38},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 39},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 40},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 41},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 42},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 43},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 44},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 45},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 46},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 47},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 48},
#     {'sub': 'sub10', 'exp': 'exp02', 'run': 'r3', 'trial': 49},
#     {'sub': 'sub12', 'exp': 'exp01', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub12', 'exp': 'exp02', 'run': 'r1', 'trial': 44},
#     {'sub': 'sub12', 'exp': 'exp02', 'run': 'r1', 'trial': 36},
#     {'sub': 'sub12', 'exp': 'exp02', 'run': 'r1', 'trial': 14},
#     {'sub': 'sub18', 'exp': 'exp01', 'run': 'r2', 'trial': 26},
#     {'sub': 'sub12', 'exp': 'exp01', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub12', 'exp': 'exp02', 'run': 'r1', 'trial': 44},
#     {'sub': 'sub12', 'exp': 'exp02', 'run': 'r1', 'trial': 14},
#     {'sub': 'sub08', 'exp': 'exp03', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub09', 'exp': 'exp01', 'run': 'r1', 'trial': 0},
#     {'sub': 'sub16', 'exp': 'exp01', 'run': 'r3', 'trial': 14},
#     {'sub': 'sub15', 'exp': 'exp01', 'run': 'r2', 'trial': 36},
#     {'sub': 'sub17', 'exp': 'exp01', 'run': 'r1', 'trial': 0}, # Session log mentions there is no pulse.
#     {'sub': 'sub17', 'exp': 'exp01', 'run': 'r1', 'trial': 1}, # Session log mentions there is no pulse.
#     {'sub': 'sub17', 'exp': 'exp01', 'run': 'r1', 'trial': 48}, # Session log mentions there is no pulse.
#     {'sub': 'sub17', 'exp': 'exp01', 'run': 'r1', 'trial': 49}, # Session log mentions there is no pulse.
# ]

rejected_trials = [
    {'sub': 'sub03', 'exp': 'exp01', 'run': 'r1', 'trial': '*'}, # We are using exp02 for this one
    {'sub': 'sub03', 'exp': 'exp01', 'run': 'r2', 'trial': '*'}, # We are using exp02 for this one
    {'sub': 'sub03', 'exp': 'exp01', 'run': 'r3', 'trial': '*'}, # We are using exp02 for this one
    
    {'sub': 'sub05', 'exp': 'exp01', 'run': 'r1', 'trial': '*'}, # BAD MEP.
    {'sub': 'sub05', 'exp': 'exp01', 'run': 'r2', 'trial': '*'}, # BAD MEP.
    
    {'sub': 'sub17', 'exp': 'exp01', 'run': 'r1', 'trial': 0}, # Session log mentions there is no pulse.
    {'sub': 'sub17', 'exp': 'exp01', 'run': 'r1', 'trial': 1}, # Session log mentions there is no pulse.
    {'sub': 'sub17', 'exp': 'exp01', 'run': 'r1', 'trial': 48}, # Session log mentions there is no pulse.
    {'sub': 'sub17', 'exp': 'exp01', 'run': 'r1', 'trial': 49}, # Session log mentions there is no pulse.
    {'sub': 'sub22', 'exp': 'exp01', 'run': 'r1', 'trial': 17}, # Session log mentions there is a problem.
    {'sub': 'sub22', 'exp': 'exp01', 'run': 'r1', 'trial': 18}, # Session log mentions there is a problem.
]

# %%
eegs
# Out:
# ['data/original/sub02/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub02/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub02/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub03/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub03/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub03/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub03/exp03/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub03/exp03/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub03/exp03/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub04/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub04/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub04/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub04/exp02/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub04/exp02/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub04/exp02/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub05/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub05/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub05/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub05/exp02/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub05/exp02/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub05/exp02/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub06/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub06/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub06/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub06/exp02/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub07/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub07/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub07/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub08/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub08/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub08/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub08/exp02/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub08/exp03/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub08/exp03/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub08/exp03/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub09/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub10/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub10/exp02/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub10/exp02/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub10/exp02/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub11/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub12/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub12/exp02/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub12/exp03/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub12/exp03/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub12/exp03/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub13/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub13/exp02/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub13/exp02/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub13/exp02/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub14/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub14/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub14/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub15/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub15/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub15/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub16/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub16/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub16/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub17/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub17/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub17/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub18/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub18/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub18/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub19/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub19/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub19/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub20/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub20/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub20/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub21/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub21/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub21/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub22/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub22/exp01/eeg/SP 110RMT r2/06-clean-prestimulus-hjorth.mat',
#  'data/original/sub22/exp01/eeg/SP 110RMT r3/06-clean-prestimulus-hjorth.mat']

# %% [markdown]
# # Basic I/O and conversions.

# %%
def read_eeg(path):
    eeg = octave.pop_loadset(path)
    new_trial_list = []
    for i in range(eeg.data.shape[2]):
        trial = eeg.data[:, :, i]
        time = np.linspace(-1000, 1000, num=trial.shape[1])
        trial = pd.DataFrame(np.transpose(trial), columns=eeg.chanlocs.labels[0])
        trial['time'] = time
        new_trial_list.append(trial)
    return new_trial_list

def read_trials_from_mat(filename):
    x = loadmat(filename)
    mat_trials = x['dat'][0][0][3][0]
    trials = []
    time = np.linspace(-1000, 1000, len(mat_trials[0][0]))
    for mat_trial in mat_trials:
        trials.append(pd.DataFrame({'C3': mat_trial[0], 'C4': mat_trial[1], 'time': time}))
    return trials

def read_trials_from_mat_avg(filename):
    x = loadmat(filename)
    mat_trials = x['dat'][0][0][3][0]
    trials = []
    time = np.linspace(-1000, 1000, len(mat_trials[0][0]))
    for mat_trial in mat_trials:
        trials.append(pd.DataFrame({
            'FC5': mat_trial[0], 
            'FC3': mat_trial[1], 
            'FC1': mat_trial[2], 
            'C5': mat_trial[3], 
            'C3': mat_trial[4], 
            'C1': mat_trial[5], 
            'CP5': mat_trial[6], 
            'CP3': mat_trial[7], 
            'CP1': mat_trial[8], 
            'FC6': mat_trial[9], 
            'FC4': mat_trial[10], 
            'FC2': mat_trial[11], 
            'C6': mat_trial[12], 
            'C4': mat_trial[13], 
            'C2': mat_trial[14], 
            'CP6': mat_trial[15], 
            'CP4': mat_trial[16], 
            'CP2': mat_trial[17], 
            'time': time
        }))
    return trials

def crop_trials(trial_list, duration_millis=500, sampling_rate=2048):
    new_trial_list = []
    for trial in trial_list:
        samples_to_pick = duration_millis * sampling_rate / 1000
        new_trial_list.append(trial.tail(int(samples_to_pick)))
    return new_trial_list, samples_to_pick

def crop_mep_region(mep_frame, crop_start=0.211, crop_end=0.4):
    multiplier = 7499 / 1.4998
    start = int(crop_start * multiplier)
    end = int(crop_end * multiplier)
    mep_cropped = mep_frame.iloc[start:end, :]
    time = mep_frame.iloc[start:end, :]
    return mep_cropped

def get_apb_column_name(mep_frame):
    if 'L APB' in mep_frame:
        return 'L APB'
    else:
        return 'APB'

def open_mep_as_df(path):
    fileMep = open(path, "r+")
    mep_frames = fileMep.read().split('\n\n')
    df_list = []
    for mep_frame in mep_frames:
        df_list.append(pd.read_csv(StringIO(mep_frame), '\t'))
    return df_list

def get_mep_path(eeg_path):
    segments = eeg_path.split('/')
    segments[4] = 'mep'
    segments = segments[:-1]
    mep_path = '/'.join(segments) + '/*.txt'
    mep_path = glob.glob(mep_path)[0]
    return mep_path

def calculate_mep_size(mep_frame, latency, duration):
    mep_cropped = crop_mep_region(mep_frame, latency, latency + duration)
    apb_name = get_apb_column_name(mep_frame)
    max_row = mep_frame.iloc[mep_cropped.idxmax(axis=0)[apb_name]]
    min_row = mep_frame.iloc[mep_cropped.idxmin(axis=0)[apb_name]]
    mep_size = max_row[apb_name] - min_row[apb_name]
    return mep_size, min_row, max_row

def read_latency_duration(eeg_path):
    segments = eeg_path.split('/')
    sub = segments[2]
    exp = segments[3]
    run = segments[5]
    path = 'data/original/' + sub + '/' + exp + '/mep/' + run + '/01-ld.csv'
    files = glob.glob(path)
    if len(files) < 1:
        return False
    fileMep = open(path, "r+")
    lines = fileMep.read().split('\n')
    df_ld = []
    for frame_txt in lines:
        if 'Frame' in frame_txt:
            continue
        segments = frame_txt.split('\t')
        if len(segments) >= 4:
            df_ld.append({
                'trial_num': int(segments[0])-1,
                'latency': float(segments[2]),
                'duration': float(segments[3]) - float(segments[2])
            })
    return pd.DataFrame(df_ld)

# Read CMAP file.
def read_cmap(path):
    df = pd.read_excel(path, sheet_name='Raw data', header=None)
    columns = []
    ix = 0
    for r in df.index.values:
        if df[0][r] == 'Channel':
            ix = r
            break
    for c in df.columns.values:
        if (df[c][ix] == 2):
            columns.append(c)
    for r in df.index.values:
        if df[0][r] == 'Time (ms)':
            ix = r
            break
    df2 = df[columns].iloc[np.linspace(ix+1, df.shape[0]-2, df.shape[0]-ix-2)]
    df2['time'] = df[0].iloc[np.linspace(ix+1, df.shape[0]-2, df.shape[0]-ix-2)]
    return df2

# Identify CMAP peaks.
def find_cmap_peaks(df):
    df2 = df[(df['time'] > 105) * (df['time'] < 120)]
    time = df2['time']
    mean_clean = np.mean(df2.drop('time', axis=1), axis=1)
    return mean_clean.max(), mean_clean.min()

def get_cmap_path(eeg_path):
    segments = eeg_path.split('/')
    segments[4] = 'cmap'
    del segments[5]
    segments = segments[:-1]
    cmap_path = '/'.join(segments) + '/*.xlsx'
    cmap_paths = glob.glob(cmap_path)
    if (len(cmap_paths) == 0):
        print('No CMAP found for ' + cmap_path)
        return ''
    return cmap_paths[0]

def get_mep_category_absolute_binary(mep_size):
    if mep_size <= .5:
        return 0
    else:
        return 1
    
def calculate_mep_categories_binary(mep_sizes):
    p1 = np.percentile(mep_sizes, 50)
    cat = np.ones(len(mep_sizes)) * (mep_sizes >= p1)
    return cat

def calculate_mep_categories_cmap_binary(mep_sizes, cmap):
    sizes = []
    for mep_size in mep_sizes:
        sizes.append(mep_size / cmap)
    p1 = np.percentile(sizes, 50)
    cat = np.ones(len(mep_sizes)) * (sizes >= p1)
    return cat

# %%
def calculate_mep_area(mep_frame, latency, duration, plot=False):
    apb_name = get_apb_column_name(mep_frame)
    mep_frame = mep_frame[(mep_frame['s'] >= latency) * (mep_frame['s'] <= latency + duration)]
    amplitude = mep_frame[apb_name]
    amplitude = np.abs(amplitude)
    time_diff = mep_frame['s'].iloc[1] - mep_frame['s'].iloc[0]
    area = trapz(amplitude, dx=time_diff)
    if (plot == True):
        plt.plot(mep_frame['s'], amplitude)
    return area
    
frames = open_mep_as_df(get_mep_path(eegs[30]))
mep_frame = frames[5]
plt.plot(mep_frame['s'], mep_frame['L APB'])
plt.xlim(.21, .28)
plt.axvline(0.225, color='r')
plt.axvline(0.25, color='r')
plt.show()
print(calculate_mep_area(mep_frame, 0.225, 0.25, plot=True))
# Out:
# 0.0138663662000004
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/pandas/core/computation/expressions.py:183: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   .format(op=op_str, alt_op=unsupported[op_str]))

# %% [markdown]
# # Power and phase calculations

# %%
def blackman_harris_filter(channel, time, cutoffs, fs, numtaps=801):
    b = signal.firwin(numtaps, cutoffs, window='blackmanharris', fs=fs)
    filtered = signal.lfilter(b, 1, channel)
    delay = 0.5 * (numtaps - 1) / fs
    df = pd.DataFrame({
        'time': time-delay,
        'channel': filtered
    })
    return df

def butter_bandpass_filter(data, lowcut, highcut, fs, btype='bandpass', order=2):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype=btype)
    y = signal.lfilter(b, a, data)
    return y

def get_phase(channel, time, band, fs=4096, plot=False, filter_type='butter', start_time_ms=-750, stop_time_ms=-2):
    if filter_type=='butter':
        df_filtered = pd.DataFrame({'channel': butter_bandpass_filter(channel, band[0], band[1], 4096), 'time': time})
    else:
        df_filtered = blackman_harris_filter(channel, time, [0.000001, band[0]], fs)
        df_filtered = blackman_harris_filter(df_filtered['channel'].values, df_filtered['time'].values, band[1], fs)    
    
    hilb = signal.hilbert(df_filtered[(df_filtered['time'] > start_time_ms) * (df_filtered['time'] < stop_time_ms)]['channel'])
    phase = np.angle(hilb, deg=True)
    df_phase = pd.DataFrame(phase, columns=['phase'])
    df_phase['time'] = df_filtered[(df_filtered['time'] > start_time_ms) * (df_filtered['time'] < stop_time_ms)]['time'].values
    
    if plot == True:
        fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(13,10))
        ax1.plot(time, channel)
        ax1.set_xlabel('Time')
        ax1.set_ylabel('Amplitude')
        ax1.set_title('Signal')
        
        ax2.plot(df_filtered['time'], df_filtered['channel'])
        ax2.set_title('Filtered channel')
        ax2.set_xlabel('Time')
        ax2.set_ylabel('Filtered channel')
        
        freq, power = signal.welch(df_filtered['channel'], 4096, nperseg=4096/2, nfft=4096/2)
        freq_res = freq[1] - freq[0]
        power = np.log(power)
        ax3.plot(freq[freq < 200], power[freq < 200])
        ax3.set_title('Power spectrum')
        ax3.set_xlabel('Frequency')
        ax3.set_ylabel('Power')
        
        ax4.plot(df_phase['time'], df_phase['phase'])
        ax4.plot(df_phase.iloc[-1]['time'], df_phase.iloc[-1]['phase'], 'o')
        ax4.set_title('Phase')
        ax4.set_xlabel('Time')
        ax4.set_ylabel('Phase')
        plt.tight_layout()
    # df_phase = df_phase[df_phase['time'] <= -20]
    return df_phase.iloc[-1]['phase'] + 180

def get_power(channel, time, band, crop_start_millis=-150, fs=500, plot=False, method='pburg', filter_type='butter'):       
    # Crop.
    channel = channel[(time > crop_start_millis) * (time < -1)].values
    time = time[(time > crop_start_millis) * (time < -1)].values

    # Resample.
    ts = time[1] - time[0]
    secs = len(channel) * ts
    secs = secs/1000
    resampled = signal.resample(channel, int(secs*fs))
    resampled_time = np.linspace(time[0], time[-1], len(resampled))
    
    # Filer if gamma region.
#     if 48 > band[0] and 48 < band[1]:
    if filter_type == 'butter':
        resampled = butter_bandpass_filter(resampled, 48, 52, fs, 'bandstop')
        resampled_time = resampled_time
    else:
        df_filtered = blackman_harris_filter(resampled, resampled_time, [48, 52], fs, numtaps=101)
        resampled = df_filtered['channel']
        resampled_time = df_filtered['time']
    
    # PSD.
    try:
        if method == 'welch':
            # Welch method
            freq, power = signal.welch(resampled, fs, nperseg=4 * fs, nfft=4 * fs)
            freq_res = freq[1] - freq[0]
            df_power = pd.DataFrame({'freq': freq, 'power': power})
            df_power_in_band = df_power[(df_power['freq'] >= band[0]) * (df_power['freq'] <= band[1])]
            mean_power = np.mean(df_power_in_band['power'])
            # idx_band = np.logical_and(freq >= band[0], freq <= band[1])
            # mean_power = simps(power[idx_band], dx=freq_res)
        elif method == 'fft':
            # FFT method
            power = np.abs(np.fft.fft(resampled, n=500))
            freq = np.linspace(0, fs, len(power))
            df_power = pd.DataFrame({'freq': freq, 'power': power})
            df_power_in_band = df_power[(df_power['freq'] >= band[0]) * (df_power['freq'] <= band[1])]
            mean_power = np.mean(df_power_in_band['power'])
        elif method == 'pburg':
            # Burgs method
            p = pburg(resampled, int(len(resampled)*.5), sampling=fs, NFFT=4096)
            power = p.psd
            freq = np.linspace(0, fs, len(power))
            df_power = pd.DataFrame({'freq': freq, 'power': power})
            df_power = df_power[df_power['freq'] < fs/2]
            df_power_in_band = df_power[(df_power['freq'] >= band[0]) * (df_power['freq'] <= band[1])]
            mean_power = np.mean(df_power_in_band['power'])
    except:
        return 0

    if plot == True:
        fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(13,10))
        ax1.plot(time, channel)
        ax1.set_title('Signal')
        ax1.set_xlabel('Time')
        ax1.set_ylabel('Amplitude')
        ax2.plot(resampled_time, resampled)
        ax2.set_title('Resampled')
        ax2.set_xlabel('Time')
        ax2.set_ylabel('Amplitude')
        ax3.plot(df_power['freq'], np.log(df_power['power']))
        ax3.axvspan(band[0], band[1], color='r', alpha=0.2)
        ax3.axhline(np.log(mean_power), color='r')
        ax3.set_xlabel('Frequency (Hz)')
        ax3.set_ylabel('Log Power')
        ax3.set_xlim([5, 100])
        ax3.set_title('Power spectrum')
        plt.tight_layout()

    return mean_power

# %%
eeg_path = eegs[50].replace('-hjorth.mat', '.set')
trials = read_eeg(eeg_path)
trial = trials[40]
trial = trial[trial['time'] < -5]

# get_power(trial['C3'], trial['time'], [8, 12], plot=True, method='welch')
# get_power(trial['C3'], trial['time'], [8, 12], plot=True, method='pburg')
# get_power(trial['C3'], trial['time'], [30, 80], plot=True)
get_phase(trial['C3'], trial['time'], [8, 12], plot=True)
# Out:
# pop_loadset(): loading file data/original/sub14/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub14/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/scipy/signal/spectral.py:1969: UserWarning: nperseg = 2048 is greater than input length  = 2038, using nperseg = 2038
#   .format(nperseg, input_length))
# 302.7121106296787

# %%
eeg_path = eegs[50]
print(eeg_path)
trials = read_trials_from_mat(eeg_path)
trial = trials[40]
trial = trial[trial['time'] < -5]

# get_power(trial['C3'], trial['time'], [8, 12], plot=True, method='welch')
# get_power(trial['C3'], trial['time'], [8, 12], plot=True, method='pburg')
# get_power(trial['C3'], trial['time'], [30, 80], plot=True)
get_phase(trial['C3'], trial['time'], [8, 12], plot=True)
# Out:
# data/original/sub14/exp01/eeg/SP 110RMT r1/06-clean-prestimulus-hjorth.mat
# 5.186488696375164

# %% [markdown]
# # Combine EEG and others

# %%
def calculate_power_phase(trial, channel):    
    phase_power_dict = {} 
    
    # −4500ms and −500ms
    # -752ms to -2ms
    # -152ms to -2ms
    
    for filter_name in ['butter', 'blackmanharris']:
        phase_power_dict['theta_phase_' + filter_name] = get_phase(trial[channel], trial['time'], [3.5, 8], filter_type=filter_name)
        phase_power_dict['mu_phase_' + filter_name] = get_phase(trial[channel], trial['time'], [8, 12], filter_type=filter_name)
        phase_power_dict['beta_phase_' + filter_name] = get_phase(trial[channel], trial['time'], [13, 30], filter_type=filter_name)
        phase_power_dict['gamma_phase_' + filter_name] = get_phase(trial[channel], trial['time'], [30, 80], filter_type=filter_name)
        phase_power_dict['low_beta_phase_' + filter_name] = get_phase(trial[channel], trial['time'], [12, 20], filter_type=filter_name)
        phase_power_dict['high_beta_phase_' + filter_name] = get_phase(trial[channel], trial['time'], [20, 30], filter_type=filter_name)
        phase_power_dict['low_gamma_phase_' + filter_name] = get_phase(trial[channel], trial['time'], [30, 46], filter_type=filter_name)
        phase_power_dict['high_gamma_phase_' + filter_name] = get_phase(trial[channel], trial['time'], [46, 70], filter_type=filter_name)

    for filter_name in ['butter', 'blackmanharris']:
        for method in ['pburg', 'welch', 'fft']:
            for crop_start in [-150, -750]:
                phase_power_dict['theta_power_' + filter_name + '_' + method + '_' + str(crop_start)] = get_power(trial[channel], trial['time'], [3.5, 8], method=method, filter_type=filter_name, crop_start_millis=crop_start)
                phase_power_dict['mu_power_' + filter_name + '_' + method + '_' + str(crop_start)] = get_power(trial[channel], trial['time'], [8, 12], method=method, filter_type=filter_name, crop_start_millis=crop_start)
                phase_power_dict['beta_power_' + filter_name + '_' + method + '_' + str(crop_start)] = get_power(trial[channel], trial['time'], [13, 30], method=method, filter_type=filter_name, crop_start_millis=crop_start)
                phase_power_dict['gamma_power_' + filter_name + '_' + method + '_' + str(crop_start)] = get_power(trial[channel], trial['time'], [30, 80], method=method, filter_type=filter_name, crop_start_millis=crop_start)
                phase_power_dict['low_beta_power_' + filter_name + '_' + method + '_' + str(crop_start)] = get_power(trial[channel], trial['time'], [12, 20], method=method, filter_type=filter_name, crop_start_millis=crop_start)
                phase_power_dict['high_beta_power_' + filter_name + '_' + method + '_' + str(crop_start)] = get_power(trial[channel], trial['time'], [20, 30], method=method, filter_type=filter_name, crop_start_millis=crop_start)
                phase_power_dict['low_gamma_power_' + filter_name + '_' + method + '_' + str(crop_start)] = get_power(trial[channel], trial['time'], [30, 46], method=method, filter_type=filter_name, crop_start_millis=crop_start)
                phase_power_dict['high_gamma_power_' + filter_name + '_' + method + '_' + str(crop_start)] = get_power(trial[channel], trial['time'], [46, 70], method=method, filter_type=filter_name, crop_start_millis=crop_start)
    
    return phase_power_dict
        
def process_trials(eeg_path):
    sub = eeg_path.split('/')[2]
    exp = eeg_path.split('/')[3]
    run = eeg_path.split('/')[5]
    
    files = glob.glob(os.path.dirname(eeg_path) + "/06-clean-prestimulus-hjorth.mat")
    if (len(files) == 0):
        return []
    
    trials = read_trials_from_mat(os.path.dirname(eeg_path) + "/06-clean-prestimulus-hjorth.mat")
    trials_raw = read_eeg(os.path.dirname(eeg_path) + "/06-clean-prestimulus.set")
    trials_avghjorth = read_trials_from_mat_avg(os.path.dirname(eeg_path) + "/08-avg-csd.mat")

    # Calculate CMAP.
    try:
        cmap_max, cmap_min = find_cmap_peaks(read_cmap(get_cmap_path(eeg_path)))
        cmap = cmap_max - cmap_min
    except:
        cmap = 0
    
    # Read latency duration
    df_ld = read_latency_duration(eeg_path)
    if isinstance(df_ld, pd.DataFrame) == False:
        return []
    
    # Calculate powers and phases. And combine the results in a df list.
    power_phase_list = []
    for trial_num in df_ld['trial_num'].values:
        if len(trials)-1 < trial_num:
            continue
        trial = trials[trial_num]
        trial_raw = trials_raw[trial_num]
        trial_avghjorth = trials_avghjorth[trial_num]
    
        # Ignore rejected trials.
        break_loop = False
        for rejected in rejected_trials:
            if (sub == rejected['sub']) and (exp == rejected['exp']) and (rejected['run'] == run.split(' ')[2]) and ((rejected['trial'] == trial_num) or (rejected['trial'] == '*')):
                print('Rejecting ' + sub + '/' + exp + '/' + run + '/' + str(rejected['trial']))
                break_loop = True
                break
        if break_loop == True or df_ld[df_ld['trial_num'] == trial_num].shape[0] == 0:
            continue
        
        # Calculate phase and power.
        # print('Processing ' + sub + '/' + exp + '/' + run + '/' + str(trial_num))
        try:
            if sub in ['sub13', 'sub02']:
                channel = 'C4'
            else:
                channel = 'C3'
            
            # Average channel
            trial2 = trial_avghjorth
            if channel == 'C4':
                channel_avg = trial2[channel] + trial2['FC6'] + trial2['FC4'] + trial2['FC2'] + trial2['C6'] + trial2['C4'] + trial2['C2'] + trial2['CP6'] + trial2['CP4'] + trial2['CP2']
            else:
                channel_avg = trial2[channel] + trial2['FC5'] + trial2['FC3'] + trial2['FC1'] + trial2['C5'] + trial2['C3'] + trial2['C1'] + trial2['CP5'] + trial2['CP3'] + trial2['CP1']
            channel_avg = channel_avg / 9
            trial2[channel] = channel_avg
            
            # Calculate powers and phases
            power_csd = calculate_power_phase(trial, channel)
            power_raw = calculate_power_phase(trial_raw, channel)
            power_csd_avg = calculate_power_phase(trial2, channel)
        except ValueError as e:
            print('Skipping ' + sub + '/' + exp + '/' + run + '/' + str(trial_num) + ': ' + str(e))
            continue

        latency = df_ld[df_ld['trial_num'] == trial_num].iloc[0]['latency']
        duration = df_ld[df_ld['trial_num'] == trial_num].iloc[0]['duration']
        mep_frame = open_mep_as_df(get_mep_path(eeg_path))[trial_num]
        mep_size, _, _ = calculate_mep_size(mep_frame, latency, duration)
        
        power_csd2 = dict()
        for key in power_csd.keys():
            power_csd2[key + '_' + 'hjorth'] = power_csd[key]
        power_csd = power_csd2
        for key in power_raw.keys():
            power_csd[key + '_' + 'raw'] = power_raw[key]
        for key in power_csd_avg.keys():
            power_csd[key + '_' + 'avghjorth'] = power_csd_avg[key]
        
        power_phase_dict = power_csd
        power_phase_dict['sub'] = sub
        power_phase_dict['exp'] = exp
        power_phase_dict['run'] = run
        power_phase_dict['trial_num'] = trial_num
        power_phase_dict['cmap'] = cmap
        power_phase_dict['mep_size'] = mep_size

        power_phase_dict['mep_latency'] = latency - 0.20
        power_phase_dict['mep_duration'] = duration
        power_phase_dict['mep_area'] = calculate_mep_area(mep_frame, latency, duration)
        
        power_phase_dict['rejected'] = False
        for rejected in rejected_trials:
            if (sub == rejected['sub']) and (exp == rejected['exp']) and (rejected['run'] == run.split(' ')[2]) and ((rejected['trial'] == trial_num) or (rejected['trial'] == '*')):
                power_phase_dict['rejected'] = True
                break

        power_phase_list.append(power_phase_dict)
    return power_phase_list

# %%
# Run analysis
results = []
for eeg_path in tqdm(eegs):
    result = process_trials(eeg_path)
    if len(result) > 0:
        results.append(result)

df_power = []
for result in results:
    if len(result) == 0:
        continue
    for trial in result:
        df_power.append(trial)

df_power = pd.DataFrame(df_power)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=77.0), HTML(value='')))
# pop_loadset(): loading file data/original/sub02/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub02/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# No CMAP found for data/original/sub02/exp01/cmap/*.xlsx
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/scipy/signal/spectral.py:1969: UserWarning: nperseg = 2000 is greater than input length  = 74, using nperseg = 74
#   .format(nperseg, input_length))
# /home/raquib/anaconda3/envs/tmseeg/lib/python3.7/site-packages/scipy/signal/spectral.py:1969: UserWarning: nperseg = 2000 is greater than input length  = 374, using nperseg = 374
#   .format(nperseg, input_length))
# pop_loadset(): loading file data/original/sub02/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub02/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# No CMAP found for data/original/sub02/exp01/cmap/*.xlsx
# pop_loadset(): loading file data/original/sub02/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub02/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# No CMAP found for data/original/sub02/exp01/cmap/*.xlsx
# pop_loadset(): loading file data/original/sub03/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub03/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# Rejecting sub03/exp01/SP 110RMT r1/*
# pop_loadset(): loading file data/original/sub03/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub03/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# Rejecting sub03/exp01/SP 110RMT r2/*
# pop_loadset(): loading file data/original/sub03/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub03/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub03/exp03/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub03/exp03/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub03/exp03/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub03/exp03/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub03/exp03/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub03/exp03/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub04/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub04/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# pop_loadset(): loading file data/original/sub04/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub04/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# pop_loadset(): loading file data/original/sub04/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub04/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# pop_loadset(): loading file data/original/sub04/exp02/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub04/exp02/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# No CMAP found for data/original/sub04/exp02/cmap/*.xlsx
# pop_loadset(): loading file data/original/sub04/exp02/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub04/exp02/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# No CMAP found for data/original/sub04/exp02/cmap/*.xlsx
# pop_loadset(): loading file data/original/sub04/exp02/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub04/exp02/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# No CMAP found for data/original/sub04/exp02/cmap/*.xlsx
# pop_loadset(): loading file data/original/sub05/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub05/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# pop_loadset(): loading file data/original/sub05/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub05/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# pop_loadset(): loading file data/original/sub05/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub05/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# pop_loadset(): loading file data/original/sub05/exp02/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub05/exp02/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub05/exp02/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub05/exp02/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub05/exp02/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub05/exp02/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# pop_loadset(): loading file data/original/sub06/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub06/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub06/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub06/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub06/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub06/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub06/exp02/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub06/exp02/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub07/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub07/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub07/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub07/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# pop_loadset(): loading file data/original/sub07/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub07/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub08/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub08/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# pop_loadset(): loading file data/original/sub08/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub08/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# pop_loadset(): loading file data/original/sub08/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub08/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# pop_loadset(): loading file data/original/sub08/exp02/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub08/exp02/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub08/exp03/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub08/exp03/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub08/exp03/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub08/exp03/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub08/exp03/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub08/exp03/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub09/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub09/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub10/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub10/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# pop_loadset(): loading file data/original/sub10/exp02/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub10/exp02/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub10/exp02/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub10/exp02/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub10/exp02/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub10/exp02/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub11/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub11/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub12/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub12/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# pop_loadset(): loading file data/original/sub12/exp02/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub12/exp02/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub12/exp03/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub12/exp03/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# pop_loadset(): loading file data/original/sub12/exp03/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub12/exp03/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub12/exp03/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub12/exp03/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub13/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub13/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub13/exp02/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub13/exp02/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub13/exp02/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub13/exp02/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub13/exp02/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub13/exp02/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub14/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub14/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub14/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub14/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub14/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub14/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub15/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub15/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub15/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub15/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# pop_loadset(): loading file data/original/sub15/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub15/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# pop_loadset(): loading file data/original/sub16/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub16/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub16/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub16/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub16/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub16/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub17/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub17/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# Rejecting sub17/exp01/SP 110RMT r1/48
# Rejecting sub17/exp01/SP 110RMT r1/49
# pop_loadset(): loading file data/original/sub17/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub17/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub17/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub17/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# pop_loadset(): loading file data/original/sub18/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub18/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub18/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub18/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub18/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub18/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub19/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub19/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub19/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub19/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub19/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub19/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# pop_loadset(): loading file data/original/sub20/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub20/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub20/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub20/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub20/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub20/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub21/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub21/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub21/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub21/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub21/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub21/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub22/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub22/exp01/eeg/SP 110RMT r1/06-clean-prestimulus.fdt'...
# Scaling components to RMS microvolt
# pop_loadset(): loading file data/original/sub22/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub22/exp01/eeg/SP 110RMT r2/06-clean-prestimulus.fdt'...
# pop_loadset(): loading file data/original/sub22/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.set ...
# Reading float file 'data/original/sub22/exp01/eeg/SP 110RMT r3/06-clean-prestimulus.fdt'...

# %%
sub_map = {
    'sub01': 'Terry Baedon',
    'sub02': 'David Brown',
    'sub03': 'Sarah Brunet',
    'sub04': 'Lynette Gallaty',
    'sub05': 'Mana Higashihara',
    'sub06': 'Tim Howells',
    'sub07': 'Merolene Pirsarkiewicz',
    'sub08': 'Steve Vucic',
    'sub09': 'Hayeley Turnbull',
    'sub10': 'Nimeshan Geevasinga',
    'sub11': 'Amarissa M',
    'sub12': 'Marshall Owen',
    'sub13': 'Stephen Schebeci',
    'sub14': 'Matt Silsby',
    'sub15': 'Carlos Brito',
    'sub16': 'Alistair McEwan',
    'sub17': 'Toni Mathieson',
    'sub18': 'Karen Robertson',
    'sub19': 'Julie Terry',
    'sub20': 'Natalie Terry',
    'sub21': 'Raquib-ul Alam',
    'sub22': 'Lin Gavin',
}

# Insert subject names
df_power['name'] = df_power.apply(lambda x: sub_map[x['sub']], axis=1)

# %%
df_power.columns.values
# Out:
# array(['beta_phase_blackmanharris_avghjorth',
#        'beta_phase_blackmanharris_hjorth',
#        'beta_phase_blackmanharris_raw', 'beta_phase_butter_avghjorth',
#        'beta_phase_butter_hjorth', 'beta_phase_butter_raw',
#        'beta_power_blackmanharris_fft_-150_avghjorth',
#        'beta_power_blackmanharris_fft_-150_hjorth',
#        'beta_power_blackmanharris_fft_-150_raw',
#        'beta_power_blackmanharris_fft_-750_avghjorth',
#        'beta_power_blackmanharris_fft_-750_hjorth',
#        'beta_power_blackmanharris_fft_-750_raw',
#        'beta_power_blackmanharris_pburg_-150_avghjorth',
#        'beta_power_blackmanharris_pburg_-150_hjorth',
#        'beta_power_blackmanharris_pburg_-150_raw',
#        'beta_power_blackmanharris_pburg_-750_avghjorth',
#        'beta_power_blackmanharris_pburg_-750_hjorth',
#        'beta_power_blackmanharris_pburg_-750_raw',
#        'beta_power_blackmanharris_welch_-150_avghjorth',
#        'beta_power_blackmanharris_welch_-150_hjorth',
#        'beta_power_blackmanharris_welch_-150_raw',
#        'beta_power_blackmanharris_welch_-750_avghjorth',
#        'beta_power_blackmanharris_welch_-750_hjorth',
#        'beta_power_blackmanharris_welch_-750_raw',
#        'beta_power_butter_fft_-150_avghjorth',
#        'beta_power_butter_fft_-150_hjorth',
#        'beta_power_butter_fft_-150_raw',
#        'beta_power_butter_fft_-750_avghjorth',
#        'beta_power_butter_fft_-750_hjorth',
#        'beta_power_butter_fft_-750_raw',
#        'beta_power_butter_pburg_-150_avghjorth',
#        'beta_power_butter_pburg_-150_hjorth',
#        'beta_power_butter_pburg_-150_raw',
#        'beta_power_butter_pburg_-750_avghjorth',
#        'beta_power_butter_pburg_-750_hjorth',
#        'beta_power_butter_pburg_-750_raw',
#        'beta_power_butter_welch_-150_avghjorth',
#        'beta_power_butter_welch_-150_hjorth',
#        'beta_power_butter_welch_-150_raw',
#        'beta_power_butter_welch_-750_avghjorth',
#        'beta_power_butter_welch_-750_hjorth',
#        'beta_power_butter_welch_-750_raw', 'cmap', 'exp',
#        'gamma_phase_blackmanharris_avghjorth',
#        'gamma_phase_blackmanharris_hjorth',
#        'gamma_phase_blackmanharris_raw', 'gamma_phase_butter_avghjorth',
#        'gamma_phase_butter_hjorth', 'gamma_phase_butter_raw',
#        'gamma_power_blackmanharris_fft_-150_avghjorth',
#        'gamma_power_blackmanharris_fft_-150_hjorth',
#        'gamma_power_blackmanharris_fft_-150_raw',
#        'gamma_power_blackmanharris_fft_-750_avghjorth',
#        'gamma_power_blackmanharris_fft_-750_hjorth',
#        'gamma_power_blackmanharris_fft_-750_raw',
#        'gamma_power_blackmanharris_pburg_-150_avghjorth',
#        'gamma_power_blackmanharris_pburg_-150_hjorth',
#        'gamma_power_blackmanharris_pburg_-150_raw',
#        'gamma_power_blackmanharris_pburg_-750_avghjorth',
#        'gamma_power_blackmanharris_pburg_-750_hjorth',
#        'gamma_power_blackmanharris_pburg_-750_raw',
#        'gamma_power_blackmanharris_welch_-150_avghjorth',
#        'gamma_power_blackmanharris_welch_-150_hjorth',
#        'gamma_power_blackmanharris_welch_-150_raw',
#        'gamma_power_blackmanharris_welch_-750_avghjorth',
#        'gamma_power_blackmanharris_welch_-750_hjorth',
#        'gamma_power_blackmanharris_welch_-750_raw',
#        'gamma_power_butter_fft_-150_avghjorth',
#        'gamma_power_butter_fft_-150_hjorth',
#        'gamma_power_butter_fft_-150_raw',
#        'gamma_power_butter_fft_-750_avghjorth',
#        'gamma_power_butter_fft_-750_hjorth',
#        'gamma_power_butter_fft_-750_raw',
#        'gamma_power_butter_pburg_-150_avghjorth',
#        'gamma_power_butter_pburg_-150_hjorth',
#        'gamma_power_butter_pburg_-150_raw',
#        'gamma_power_butter_pburg_-750_avghjorth',
#        'gamma_power_butter_pburg_-750_hjorth',
#        'gamma_power_butter_pburg_-750_raw',
#        'gamma_power_butter_welch_-150_avghjorth',
#        'gamma_power_butter_welch_-150_hjorth',
#        'gamma_power_butter_welch_-150_raw',
#        'gamma_power_butter_welch_-750_avghjorth',
#        'gamma_power_butter_welch_-750_hjorth',
#        'gamma_power_butter_welch_-750_raw',
#        'high_beta_phase_blackmanharris_avghjorth',
#        'high_beta_phase_blackmanharris_hjorth',
#        'high_beta_phase_blackmanharris_raw',
#        'high_beta_phase_butter_avghjorth',
#        'high_beta_phase_butter_hjorth', 'high_beta_phase_butter_raw',
#        'high_beta_power_blackmanharris_fft_-150_avghjorth',
#        'high_beta_power_blackmanharris_fft_-150_hjorth',
#        'high_beta_power_blackmanharris_fft_-150_raw',
#        'high_beta_power_blackmanharris_fft_-750_avghjorth',
#        'high_beta_power_blackmanharris_fft_-750_hjorth',
#        'high_beta_power_blackmanharris_fft_-750_raw',
#        'high_beta_power_blackmanharris_pburg_-150_avghjorth',
#        'high_beta_power_blackmanharris_pburg_-150_hjorth',
#        'high_beta_power_blackmanharris_pburg_-150_raw',
#        'high_beta_power_blackmanharris_pburg_-750_avghjorth',
#        'high_beta_power_blackmanharris_pburg_-750_hjorth',
#        'high_beta_power_blackmanharris_pburg_-750_raw',
#        'high_beta_power_blackmanharris_welch_-150_avghjorth',
#        'high_beta_power_blackmanharris_welch_-150_hjorth',
#        'high_beta_power_blackmanharris_welch_-150_raw',
#        'high_beta_power_blackmanharris_welch_-750_avghjorth',
#        'high_beta_power_blackmanharris_welch_-750_hjorth',
#        'high_beta_power_blackmanharris_welch_-750_raw',
#        'high_beta_power_butter_fft_-150_avghjorth',
#        'high_beta_power_butter_fft_-150_hjorth',
#        'high_beta_power_butter_fft_-150_raw',
#        'high_beta_power_butter_fft_-750_avghjorth',
#        'high_beta_power_butter_fft_-750_hjorth',
#        'high_beta_power_butter_fft_-750_raw',
#        'high_beta_power_butter_pburg_-150_avghjorth',
#        'high_beta_power_butter_pburg_-150_hjorth',
#        'high_beta_power_butter_pburg_-150_raw',
#        'high_beta_power_butter_pburg_-750_avghjorth',
#        'high_beta_power_butter_pburg_-750_hjorth',
#        'high_beta_power_butter_pburg_-750_raw',
#        'high_beta_power_butter_welch_-150_avghjorth',
#        'high_beta_power_butter_welch_-150_hjorth',
#        'high_beta_power_butter_welch_-150_raw',
#        'high_beta_power_butter_welch_-750_avghjorth',
#        'high_beta_power_butter_welch_-750_hjorth',
#        'high_beta_power_butter_welch_-750_raw',
#        'high_gamma_phase_blackmanharris_avghjorth',
#        'high_gamma_phase_blackmanharris_hjorth',
#        'high_gamma_phase_blackmanharris_raw',
#        'high_gamma_phase_butter_avghjorth',
#        'high_gamma_phase_butter_hjorth', 'high_gamma_phase_butter_raw',
#        'high_gamma_power_blackmanharris_fft_-150_avghjorth',
#        'high_gamma_power_blackmanharris_fft_-150_hjorth',
#        'high_gamma_power_blackmanharris_fft_-150_raw',
#        'high_gamma_power_blackmanharris_fft_-750_avghjorth',
#        'high_gamma_power_blackmanharris_fft_-750_hjorth',
#        'high_gamma_power_blackmanharris_fft_-750_raw',
#        'high_gamma_power_blackmanharris_pburg_-150_avghjorth',
#        'high_gamma_power_blackmanharris_pburg_-150_hjorth',
#        'high_gamma_power_blackmanharris_pburg_-150_raw',
#        'high_gamma_power_blackmanharris_pburg_-750_avghjorth',
#        'high_gamma_power_blackmanharris_pburg_-750_hjorth',
#        'high_gamma_power_blackmanharris_pburg_-750_raw',
#        'high_gamma_power_blackmanharris_welch_-150_avghjorth',
#        'high_gamma_power_blackmanharris_welch_-150_hjorth',
#        'high_gamma_power_blackmanharris_welch_-150_raw',
#        'high_gamma_power_blackmanharris_welch_-750_avghjorth',
#        'high_gamma_power_blackmanharris_welch_-750_hjorth',
#        'high_gamma_power_blackmanharris_welch_-750_raw',
#        'high_gamma_power_butter_fft_-150_avghjorth',
#        'high_gamma_power_butter_fft_-150_hjorth',
#        'high_gamma_power_butter_fft_-150_raw',
#        'high_gamma_power_butter_fft_-750_avghjorth',
#        'high_gamma_power_butter_fft_-750_hjorth',
#        'high_gamma_power_butter_fft_-750_raw',
#        'high_gamma_power_butter_pburg_-150_avghjorth',
#        'high_gamma_power_butter_pburg_-150_hjorth',
#        'high_gamma_power_butter_pburg_-150_raw',
#        'high_gamma_power_butter_pburg_-750_avghjorth',
#        'high_gamma_power_butter_pburg_-750_hjorth',
#        'high_gamma_power_butter_pburg_-750_raw',
#        'high_gamma_power_butter_welch_-150_avghjorth',
#        'high_gamma_power_butter_welch_-150_hjorth',
#        'high_gamma_power_butter_welch_-150_raw',
#        'high_gamma_power_butter_welch_-750_avghjorth',
#        'high_gamma_power_butter_welch_-750_hjorth',
#        'high_gamma_power_butter_welch_-750_raw',
#        'low_beta_phase_blackmanharris_avghjorth',
#        'low_beta_phase_blackmanharris_hjorth',
#        'low_beta_phase_blackmanharris_raw',
#        'low_beta_phase_butter_avghjorth', 'low_beta_phase_butter_hjorth',
#        'low_beta_phase_butter_raw',
#        'low_beta_power_blackmanharris_fft_-150_avghjorth',
#        'low_beta_power_blackmanharris_fft_-150_hjorth',
#        'low_beta_power_blackmanharris_fft_-150_raw',
#        'low_beta_power_blackmanharris_fft_-750_avghjorth',
#        'low_beta_power_blackmanharris_fft_-750_hjorth',
#        'low_beta_power_blackmanharris_fft_-750_raw',
#        'low_beta_power_blackmanharris_pburg_-150_avghjorth',
#        'low_beta_power_blackmanharris_pburg_-150_hjorth',
#        'low_beta_power_blackmanharris_pburg_-150_raw',
#        'low_beta_power_blackmanharris_pburg_-750_avghjorth',
#        'low_beta_power_blackmanharris_pburg_-750_hjorth',
#        'low_beta_power_blackmanharris_pburg_-750_raw',
#        'low_beta_power_blackmanharris_welch_-150_avghjorth',
#        'low_beta_power_blackmanharris_welch_-150_hjorth',
#        'low_beta_power_blackmanharris_welch_-150_raw',
#        'low_beta_power_blackmanharris_welch_-750_avghjorth',
#        'low_beta_power_blackmanharris_welch_-750_hjorth',
#        'low_beta_power_blackmanharris_welch_-750_raw',
#        'low_beta_power_butter_fft_-150_avghjorth',
#        'low_beta_power_butter_fft_-150_hjorth',
#        'low_beta_power_butter_fft_-150_raw',
#        'low_beta_power_butter_fft_-750_avghjorth',
#        'low_beta_power_butter_fft_-750_hjorth',
#        'low_beta_power_butter_fft_-750_raw',
#        'low_beta_power_butter_pburg_-150_avghjorth',
#        'low_beta_power_butter_pburg_-150_hjorth',
#        'low_beta_power_butter_pburg_-150_raw',
#        'low_beta_power_butter_pburg_-750_avghjorth',
#        'low_beta_power_butter_pburg_-750_hjorth',
#        'low_beta_power_butter_pburg_-750_raw',
#        'low_beta_power_butter_welch_-150_avghjorth',
#        'low_beta_power_butter_welch_-150_hjorth',
#        'low_beta_power_butter_welch_-150_raw',
#        'low_beta_power_butter_welch_-750_avghjorth',
#        'low_beta_power_butter_welch_-750_hjorth',
#        'low_beta_power_butter_welch_-750_raw',
#        'low_gamma_phase_blackmanharris_avghjorth',
#        'low_gamma_phase_blackmanharris_hjorth',
#        'low_gamma_phase_blackmanharris_raw',
#        'low_gamma_phase_butter_avghjorth',
#        'low_gamma_phase_butter_hjorth', 'low_gamma_phase_butter_raw',
#        'low_gamma_power_blackmanharris_fft_-150_avghjorth',
#        'low_gamma_power_blackmanharris_fft_-150_hjorth',
#        'low_gamma_power_blackmanharris_fft_-150_raw',
#        'low_gamma_power_blackmanharris_fft_-750_avghjorth',
#        'low_gamma_power_blackmanharris_fft_-750_hjorth',
#        'low_gamma_power_blackmanharris_fft_-750_raw',
#        'low_gamma_power_blackmanharris_pburg_-150_avghjorth',
#        'low_gamma_power_blackmanharris_pburg_-150_hjorth',
#        'low_gamma_power_blackmanharris_pburg_-150_raw',
#        'low_gamma_power_blackmanharris_pburg_-750_avghjorth',
#        'low_gamma_power_blackmanharris_pburg_-750_hjorth',
#        'low_gamma_power_blackmanharris_pburg_-750_raw',
#        'low_gamma_power_blackmanharris_welch_-150_avghjorth',
#        'low_gamma_power_blackmanharris_welch_-150_hjorth',
#        'low_gamma_power_blackmanharris_welch_-150_raw',
#        'low_gamma_power_blackmanharris_welch_-750_avghjorth',
#        'low_gamma_power_blackmanharris_welch_-750_hjorth',
#        'low_gamma_power_blackmanharris_welch_-750_raw',
#        'low_gamma_power_butter_fft_-150_avghjorth',
#        'low_gamma_power_butter_fft_-150_hjorth',
#        'low_gamma_power_butter_fft_-150_raw',
#        'low_gamma_power_butter_fft_-750_avghjorth',
#        'low_gamma_power_butter_fft_-750_hjorth',
#        'low_gamma_power_butter_fft_-750_raw',
#        'low_gamma_power_butter_pburg_-150_avghjorth',
#        'low_gamma_power_butter_pburg_-150_hjorth',
#        'low_gamma_power_butter_pburg_-150_raw',
#        'low_gamma_power_butter_pburg_-750_avghjorth',
#        'low_gamma_power_butter_pburg_-750_hjorth',
#        'low_gamma_power_butter_pburg_-750_raw',
#        'low_gamma_power_butter_welch_-150_avghjorth',
#        'low_gamma_power_butter_welch_-150_hjorth',
#        'low_gamma_power_butter_welch_-150_raw',
#        'low_gamma_power_butter_welch_-750_avghjorth',
#        'low_gamma_power_butter_welch_-750_hjorth',
#        'low_gamma_power_butter_welch_-750_raw', 'mep_area',
#        'mep_duration', 'mep_latency', 'mep_size',
#        'mu_phase_blackmanharris_avghjorth',
#        'mu_phase_blackmanharris_hjorth', 'mu_phase_blackmanharris_raw',
#        'mu_phase_butter_avghjorth', 'mu_phase_butter_hjorth',
#        'mu_phase_butter_raw',
#        'mu_power_blackmanharris_fft_-150_avghjorth',
#        'mu_power_blackmanharris_fft_-150_hjorth',
#        'mu_power_blackmanharris_fft_-150_raw',
#        'mu_power_blackmanharris_fft_-750_avghjorth',
#        'mu_power_blackmanharris_fft_-750_hjorth',
#        'mu_power_blackmanharris_fft_-750_raw',
#        'mu_power_blackmanharris_pburg_-150_avghjorth',
#        'mu_power_blackmanharris_pburg_-150_hjorth',
#        'mu_power_blackmanharris_pburg_-150_raw',
#        'mu_power_blackmanharris_pburg_-750_avghjorth',
#        'mu_power_blackmanharris_pburg_-750_hjorth',
#        'mu_power_blackmanharris_pburg_-750_raw',
#        'mu_power_blackmanharris_welch_-150_avghjorth',
#        'mu_power_blackmanharris_welch_-150_hjorth',
#        'mu_power_blackmanharris_welch_-150_raw',
#        'mu_power_blackmanharris_welch_-750_avghjorth',
#        'mu_power_blackmanharris_welch_-750_hjorth',
#        'mu_power_blackmanharris_welch_-750_raw',
#        'mu_power_butter_fft_-150_avghjorth',
#        'mu_power_butter_fft_-150_hjorth', 'mu_power_butter_fft_-150_raw',
#        'mu_power_butter_fft_-750_avghjorth',
#        'mu_power_butter_fft_-750_hjorth', 'mu_power_butter_fft_-750_raw',
#        'mu_power_butter_pburg_-150_avghjorth',
#        'mu_power_butter_pburg_-150_hjorth',
#        'mu_power_butter_pburg_-150_raw',
#        'mu_power_butter_pburg_-750_avghjorth',
#        'mu_power_butter_pburg_-750_hjorth',
#        'mu_power_butter_pburg_-750_raw',
#        'mu_power_butter_welch_-150_avghjorth',
#        'mu_power_butter_welch_-150_hjorth',
#        'mu_power_butter_welch_-150_raw',
#        'mu_power_butter_welch_-750_avghjorth',
#        'mu_power_butter_welch_-750_hjorth',
#        'mu_power_butter_welch_-750_raw', 'rejected', 'run', 'sub',
#        'theta_phase_blackmanharris_avghjorth',
#        'theta_phase_blackmanharris_hjorth',
#        'theta_phase_blackmanharris_raw', 'theta_phase_butter_avghjorth',
#        'theta_phase_butter_hjorth', 'theta_phase_butter_raw',
#        'theta_power_blackmanharris_fft_-150_avghjorth',
#        'theta_power_blackmanharris_fft_-150_hjorth',
#        'theta_power_blackmanharris_fft_-150_raw',
#        'theta_power_blackmanharris_fft_-750_avghjorth',
#        'theta_power_blackmanharris_fft_-750_hjorth',
#        'theta_power_blackmanharris_fft_-750_raw',
#        'theta_power_blackmanharris_pburg_-150_avghjorth',
#        'theta_power_blackmanharris_pburg_-150_hjorth',
#        'theta_power_blackmanharris_pburg_-150_raw',
#        'theta_power_blackmanharris_pburg_-750_avghjorth',
#        'theta_power_blackmanharris_pburg_-750_hjorth',
#        'theta_power_blackmanharris_pburg_-750_raw',
#        'theta_power_blackmanharris_welch_-150_avghjorth',
#        'theta_power_blackmanharris_welch_-150_hjorth',
#        'theta_power_blackmanharris_welch_-150_raw',
#        'theta_power_blackmanharris_welch_-750_avghjorth',
#        'theta_power_blackmanharris_welch_-750_hjorth',
#        'theta_power_blackmanharris_welch_-750_raw',
#        'theta_power_butter_fft_-150_avghjorth',
#        'theta_power_butter_fft_-150_hjorth',
#        'theta_power_butter_fft_-150_raw',
#        'theta_power_butter_fft_-750_avghjorth',
#        'theta_power_butter_fft_-750_hjorth',
#        'theta_power_butter_fft_-750_raw',
#        'theta_power_butter_pburg_-150_avghjorth',
#        'theta_power_butter_pburg_-150_hjorth',
#        'theta_power_butter_pburg_-150_raw',
#        'theta_power_butter_pburg_-750_avghjorth',
#        'theta_power_butter_pburg_-750_hjorth',
#        'theta_power_butter_pburg_-750_raw',
#        'theta_power_butter_welch_-150_avghjorth',
#        'theta_power_butter_welch_-150_hjorth',
#        'theta_power_butter_welch_-150_raw',
#        'theta_power_butter_welch_-750_avghjorth',
#        'theta_power_butter_welch_-750_hjorth',
#        'theta_power_butter_welch_-750_raw', 'trial_num', 'name',
#        'sub_exp', 'sub_exp_run_trial'], dtype=object)

# %%
# Show subject histogram and remove subjects with fewer trials
df_power['sub_exp'] = df_power['sub'] + "_" + df_power['exp']
df_power = df_power[~df_power['sub_exp'].isin(['sub04_exp01', 'sub14_exp01'])]
df_power['sub_exp'].hist(figsize=(19,4), xrot=90, bins=50, align='mid')

# Create unique ID
df_power['sub_exp_run_trial'] = df_power['sub_exp'] + "_" + df_power['run'].astype(str) + '_' + df_power['trial_num'].astype(str)

# Log transform powers
for eeg_type in ['hjorth', 'raw', 'avghjorth']:
    for filter_name in ['butter', 'blackmanharris']:
        for method in ['pburg', 'welch', 'fft']:
            for band in ['theta_power', 'mu_power', 'beta_power', 'gamma_power']:
                for time in ['-750', '-150']:
                    df_power[band + '_' + filter_name + '_' + method + '_' + time + '_' + eeg_type + '_log'] = np.log(df_power[band + '_' + filter_name + '_' + method + '_' + time + '_' + eeg_type])
                
# Save the dataframe
df_power.to_excel('153-power-variation-wideformat.xlsx')
df_power.head()
# Out:
#    beta_phase_blackmanharris_avghjorth  beta_phase_blackmanharris_hjorth  \
# 0                           249.710873                        248.215454
# 1                            53.176036                         49.679123
# 2                           236.195439                        237.831537
# 3                             9.273974                        350.914701
# 4                           247.815704                        242.249550
#
#    beta_phase_blackmanharris_raw  beta_phase_butter_avghjorth  \
# 0                     247.922423                   287.990582
# 1                      49.726242                   238.306681
# 2                     237.987791                    72.731638
# 3                       8.552609                    68.830872
# 4                     243.497877                    99.810868
#
#    beta_phase_butter_hjorth  beta_phase_butter_raw  \
# 0                323.583089             326.738887
# 1                230.672487             229.648103
# 2                144.295572             124.768304
# 3                 68.763485              67.929836
# 4                 98.361251             104.745021
#
#    beta_power_blackmanharris_fft_-150_avghjorth  \
# 0                                     91.137585
# 1                                     80.185431
# 2                                     53.329748
# 3                                    104.778923
# 4                                     29.572672
#
#    beta_power_blackmanharris_fft_-150_hjorth  \
# 0                                 572.515447
# 1                                 431.123270
# 2                                 275.883306
# 3                                 606.223805
# 4                                 225.649915
#
#    beta_power_blackmanharris_fft_-150_raw  \
# 0                              567.188102
# 1                              403.350290
# 2                              255.567015
# 3                              585.713494
# 4                              247.446836
#
#    beta_power_blackmanharris_fft_-750_avghjorth  ...  \
# 0                                    152.119906  ...
# 1                                    225.064307  ...
# 2                                    187.920189  ...
# 3                                    215.774320  ...
# 4                                    203.206487  ...
#
#    gamma_power_blackmanharris_welch_-750_avghjorth_log  \
# 0                                          -1.407081
# 1                                          -1.298207
# 2                                          -1.124361
# 3                                          -1.464283
# 4                                          -1.120946
#
#    gamma_power_blackmanharris_welch_-150_avghjorth_log  \
# 0                                          -1.218032
# 1                                          -2.763722
# 2                                          -4.508895
# 3                                          -1.884916
# 4                                          -3.240258
#
#    theta_power_blackmanharris_fft_-750_avghjorth_log  \
# 0                                           5.968073
# 1                                           5.997475
# 2                                           6.259447
# 3                                           6.399465
# 4                                           5.565282
#
#    theta_power_blackmanharris_fft_-150_avghjorth_log  \
# 0                                           5.792913
# 1                                           5.827299
# 2                                           3.437338
# 3                                           6.114569
# 4                                           3.757942
#
#    mu_power_blackmanharris_fft_-750_avghjorth_log  \
# 0                                        5.192472
# 1                                        5.672503
# 2                                        5.769434
# 3                                        5.205614
# 4                                        4.799749
#
#    mu_power_blackmanharris_fft_-150_avghjorth_log  \
# 0                                        5.499352
# 1                                        5.601876
# 2                                        3.604595
# 3                                        5.857856
# 4                                        3.485177
#
#    beta_power_blackmanharris_fft_-750_avghjorth_log  \
# 0                                          5.024669
# 1                                          5.416386
# 2                                          5.236017
# 3                                          5.374233
# 4                                          5.314223
#
#    beta_power_blackmanharris_fft_-150_avghjorth_log  \
# 0                                          4.512370
# 1                                          4.384342
# 2                                          3.976494
# 3                                          4.651853
# 4                                          3.386851
#
#    gamma_power_blackmanharris_fft_-750_avghjorth_log  \
# 0                                           5.008734
# 1                                           5.044394
# 2                                           4.862118
# 3                                           4.884118
# 4                                           4.872410
#
#    gamma_power_blackmanharris_fft_-150_avghjorth_log
# 0                                           4.247075
# 1                                           3.645815
# 2                                           3.592605
# 3                                           4.334097
# 4                                           3.462676
#
# [5 rows x 493 columns]

# %%
# Long format - phase
value_vars = []
for eeg_type in ['hjorth', 'raw', 'avghjorth']:
    for filter_type in ['butter', 'blackmanharris']:
        for band in ['theta', 'mu', 'beta', 'gamma']:
            for time in ['-750', '-150']:
                for method in ['fft', 'welch', 'pburg']:
                    value_vars.append(band + '_power_' + filter_type + '_' + method + '_' + time + '_' + eeg_type + '_log')
df_melt = pd.melt(df_power, id_vars=['sub_exp_run_trial'], value_vars=value_vars)

# Rename some variables
method_map = dict()
method_map = {
    'fft': 'FFT',
    'welch': 'Welch',
    'pburg': 'Burg'
}
eeg_type_map = {
    'raw': 'Raw',
    'hjorth': 'Hjorth',
    'avghjorth': 'Average (Hjorth)'
}
df_melt['Method'] = df_melt['variable'].apply(lambda x: method_map[x.split('_')[3]])
df_melt['Band'] = df_melt['variable'].apply(lambda x: x.split('_')[0].capitalize())
df_melt['Filter'] = df_melt['variable'].apply(lambda x: x.split('_')[2].capitalize())
df_melt['Time'] = df_melt['variable'].apply(lambda x: str(x.split('_')[4]))
df_melt['EEG'] = df_melt['variable'].apply(lambda x: eeg_type_map[x.split('_')[5]])
df_melt['sub'] = df_melt['sub_exp_run_trial'].apply(lambda x: x.split('_')[0])
df_melt['exp'] = df_melt['sub_exp_run_trial'].apply(lambda x: x.split('_')[1])
df_melt['run'] = df_melt['sub_exp_run_trial'].apply(lambda x: x.split('_')[2])
df_melt['trial'] = df_melt['sub_exp_run_trial'].apply(lambda x: x.split('_')[3])

df_melt = df_melt.sort_values(['Method', 'Band', 'Filter', 'Time', 'EEG', 'sub', 'exp', 'run', 'trial'])
df_new = []
for method in tqdm(['Burg', 'FFT', 'Welch']):
    for band in tqdm(['Theta', 'Mu', 'Beta', 'Gamma']):
        for filt in ['Blackmanharris', 'Butter']:
            for time in ['-750', '-150']:
                for eeg in ['Average (Hjorth)', 'Raw', 'Hjorth']:
                    for sub in df_melt['sub'].unique():
                        i = 0
                        df_sub = df_melt[df_melt['Method'] == method]
                        df_sub = df_sub[df_sub['Band'] == band]
                        df_sub = df_sub[df_sub['Filter'] == filt]
                        df_sub = df_sub[df_sub['Time'] == time]
                        df_sub = df_sub[df_sub['EEG'] == eeg]
                        df_sub = df_sub[df_sub['sub'] == sub]
                        for idx, row in df_sub.iterrows():
                            row = row.to_dict()
                            row['trial_abs'] = i
                            df_new.append(row)
                            i = i+1
df_melt = pd.DataFrame(df_new)
print(df_melt.shape)
df_melt.to_excel('153-power-variation-longformat.xlsx')
# Out:
# (385344, 12)

# %%
# Long format - phase
value_vars = []
for eeg_type in ['hjorth', 'raw', 'avghjorth']:
    for filter_type in ['butter', 'blackmanharris']:
        for band in ['theta', 'mu', 'beta', 'gamma']:
            value_vars.append(band + '_phase_' + filter_type + '_' + eeg_type) # mu_phase_blackmanharris_avghjorth
df_melt = pd.melt(df_power, id_vars=['sub_exp_run_trial'], value_vars=value_vars)

# Rename some variables
df_melt['Band'] = df_melt['variable'].apply(lambda x: x.split('_')[0].capitalize())
df_melt['Filter'] = df_melt['variable'].apply(lambda x: x.split('_')[2].capitalize())
df_melt['EEG'] = df_melt['variable'].apply(lambda x: eeg_type_map[x.split('_')[3]])
df_melt['sub'] = df_melt['sub_exp_run_trial'].apply(lambda x: x.split('_')[0])
df_melt['exp'] = df_melt['sub_exp_run_trial'].apply(lambda x: x.split('_')[1])
df_melt['run'] = df_melt['sub_exp_run_trial'].apply(lambda x: x.split('_')[2])
df_melt['trial'] = df_melt['sub_exp_run_trial'].apply(lambda x: x.split('_')[3])

# Generate absolute trial numbers
df_melt = df_melt.sort_values(['Band', 'Filter', 'EEG', 'sub', 'exp', 'run', 'trial'])
subs = df_melt['sub'].unique()
df_new = []
for band in tqdm(['Theta', 'Mu', 'Beta', 'Gamma']):
    for filt in ['Blackmanharris', 'Butter']:
        for eeg in ['Average (Hjorth)', 'Raw', 'Hjorth']:
            for sub in subs:
                i = 0
                df_sub = df_melt[df_melt['Band'] == band]
                df_sub = df_sub[df_sub['Filter'] == filt]
                df_sub = df_sub[df_sub['EEG'] == eeg]
                df_sub = df_sub[df_sub['sub'] == sub]
                for idx, row in df_sub.iterrows():
                    row = row.to_dict()
                    row['trial_abs'] = i
                    df_new.append(row)
                    i = i+1
df_melt = pd.DataFrame(df_new)
print(df_melt.shape)
df_melt.to_excel('153-phase-variation-longformat.xlsx')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=4.0), HTML(value='')))
# (64224, 11)

# %%
# Effect of PSD method
with plt.style.context(['science-raquib']):
    sns.catplot(x="Band", y="value", hue="Method", col="Filter", data=df_melt, kind="box", height=4, aspect=1.2, palette="bright", fliersize=0)
    sns.catplot(x="Band", y="value", hue="Filter", col="Method", data=df_melt, kind="box", height=4, aspect=1, palette="bright", fliersize=0)
    sns.catplot(x="Band", y="value", hue="Method", col="EEG", data=df_melt, kind="box", height=4, aspect=1, palette="bright", fliersize=0)
    sns.catplot(x="Band", y="value", hue="Filter", col="EEG", data=df_melt, kind="box", height=4, aspect=1, palette="bright", fliersize=0)

# %% [markdown]
# # Trial plot

# %%
df_melt = pd.read_excel('153-power-variation-longformat.xlsx')
df_melt.shape

# %%
df_melt.head()

# %%
df_melt['trial_abs'].hist()

# %%
fig, axs = plt.subplots(3,1, figsize=(12,12))
i = 0
for eeg in ['Hjorth', 'Raw', 'Average (Hjorth)']:
    df = df_melt[df_melt['Filter'] == 'Butter']
    df = df[df['EEG'] == eeg]
    df = df[df['sub'] == 'sub10']
    df = df[df['Band'] == 'Beta']
    print(df['exp'].unique())
    print(df.shape)
    sns.lineplot(x="trial_abs", y="value", hue="Method", data=df, ci='sd', ax=axs[i])
    axs[i].set_title(eeg)
    i = i + 1
plt.tight_layout()
